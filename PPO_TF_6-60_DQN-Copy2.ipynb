# %%
#import PPO_A2C 
#import Dual_Connect_2 as Dual_Connect
import DQN_40_B as PPO_A2C_SEQ
import STHD_1 as Dual_Connect

import pandas as pd
import multiprocessing as mp
import datetime
import math
import random
import numpy as np
import matplotlib.pyplot as plt
import os
import torch

from typing import Type

# %%
class PPO_TF_HO_Algo(Dual_Connect.Handover):
    
    #def init_connect_cell(self, RL_Agent:Type[PPO_A2C_SEQ.PPO], RL_input, delay_buffer,\
    #                      graph_edge, node_features, new_graph_edge, num_of_UE, num_of_micro):
    def init_connect_cell(self, RL_Agent:Type[PPO_A2C_SEQ.PPO], RL_input, num_of_UE, num_of_st, angle_time_table,\
                         servering_st, c_st, E):
        
        done = False
                    
        action = RL_Agent.select_action(RL_input, self.time, num_of_UE, num_of_st, c_st ,E)
        
        

        self.s_cell['cell_type'][0] = 'ST'
        self.s_cell['cell_ID'][0] = action
        self.angle=angle_time_table[self.time][action]
        self.ini = True
        RL_Agent.buffer.is_terminals.append(done)
        
        servering_st[action]+=1

        
        
        #RL_Agent.buffer.is_terminals.append(done)
        #RL_Agent.buffer.UE_ID.append(self.ID)
        #RL_Agent.buffer.UE_ID.append(self.ID)
        #delay_buffer.append('S')
        #delay_buffer.append('S')    
        #self.A2_start = 1
        #self.A2_index = len(delay_buffer)-1
        #print(Rank) 
        
        '''
        for i in range(len(Rank)):
            
            self.s_cell['cell_type'][0]='micro'
            self.s_cell['cell_ID'][0]=action_1
            if action_2 != num_of_micro:

                self.s_cell['cell_type'][1]='micro'
                self.s_cell['cell_ID'][1]=action_2
            else:
                self.s_cell['cell_type'][1]=[]
                self.s_cell['cell_ID'][1]=[]
            #print(self.s_cell['cell_ID'][i] )
            self.s_cell['SINR'][i] = \
            float(self.df[str(self.s_cell['cell_type'][i]) + '_' + str(self.s_cell['cell_ID'][i]) + '_SINR'][self.time])
            self.s_cell['RSRP'][i] = \
            float(self.df[str(self.s_cell['cell_type'][i]) + '_' + str(self.s_cell['cell_ID'][i]) + '_L3_RSRP'][self.time])
            self.connection[i] = 1
            
            ##print('cell_ID '+str(self.s_cell['cell_ID'][i]))
            ##print('ID '+ str(self.ID))
            graph_edge[int(self.ID)][int(self.s_cell['cell_ID'][i])]=1
            se = float(self.df[str(self.s_cell['cell_type'][i]) +\
                '_' + str(self.s_cell['cell_ID'][i])+'_SINR'][self.time])
                    
            node_features[int(self.ID)][int(self.s_cell['cell_ID'][i])]=(Dual_Connect.mcs_rule(se))/5.555
        #print('----------------------')
        #print('UE ini :'+str(self.ID))
        #print('UE s :'+str(self.s_cell['cell_ID']))
        #print('new_g ' +str(graph_edge[self.ID]))
        #print('new_f ' +str( node_features[self.ID]))
        #print('need_reward'+str(self.A2_index))
        self.position_x = self.df['position_x'][self.time]
        self.position_y = self.df['position_y'][self.time]
        self.ini = True
        
        #print('______________')
        #print(self.ID)
        #print('ini index')
        #print(self.A2_index)
        #print(self.s_cell['cell_ID'])
        #print('______________')
        
        
        #print(str(self.ID)+ 'ini')
        '''
    #def TF_handover(self, RL_Agent:Type[PPO_A2C_SEQ.PPO], RL_input, delay_buffer,\
    #                      graph_edge, node_features, new_graph_edge, num_of_UE, num_of_micro):
    
    
    def TF_handover(self, RL_Agent:Type[PPO_A2C_SEQ.PPO], RL_input, num_of_UE, num_of_st, servering_st, c_st, E):
        
        done = False
        
        
        
        #action = RL_Agent.select_action(RL_input, self.time_step, th, graph_edge, node_features, new_graph_edge,\
        #                                                        num_of_UE, num_of_micro)
          
        action = RL_Agent.select_action(RL_input, self.time, num_of_UE, num_of_st, c_st, E)
        
        #print('action')
        #print(action)
        
        if action !=  self.s_cell['cell_ID'][0] :
            
            self.HO_count += 1
            
            servering_st[self.s_cell['cell_ID'][0]]-=1
            
            self.s_cell['cell_ID'][0] = action

            servering_st[action]+=1
        
        
     
        
        
        
        HO_state = 'M'
        
        #self.t_cell['cell_type'][0] = 'ST'
        #self.t_cell['cell_ID'][0] = action

        #HO_state = 'H_R'      

        #if(self.time == 600-1):
        #    done = True
            
        RL_Agent.buffer.is_terminals.append(done)
            
            
            
        return HO_state
            

        #return HO_state, A2_event
        
    
    #def handover(self,RL_Agent, RL_input, delay_buffer, graph_edge, node_features,\
    #             new_graph_edge, num_of_UE, num_of_micro):

    def handover(self,RL_Agent, RL_input, num_of_UE, num_of_st, servering_st,c_st,E):
        
        #A2_Event=False
        HO_state = self.HO_state

        #self.All_cell_connect_test()     

        #if self.RLF == 1:

        #    self.RLF_reset()
        #    self.RLF_count +=1

        #else:

        if HO_state == 'M':
                    
            #HO_state,A2_Event = self.TF_handover(RL_Agent, RL_input, delay_buffer,\
            #                    graph_edge, node_features, new_graph_edge, num_of_UE, num_of_micro)               
            HO_state = self.TF_handover(RL_Agent, RL_input, num_of_UE, num_of_st, servering_st, c_st, E)                

        #elif HO_state == 'H_R':
        #    HO_state = self.HO_success_process()

        #elif HO_state == 'H_R' and self.s_cell['cell_ID'][0] != [] or self.s_cell['cell_ID'][1] != []:
        #    HO_state = self.HO_success_process(graph_edge,node_features)


        else:
            print('error')
            
        self.HO_state = HO_state

# %%
def UE_data_to_csv(case ,em_name, algo_name ,num_ue):
    
    path = case + '_'+ em_name + '_' + algo_name +'_'+ num_ue
    folder = os.path.exists(path)    
    if not folder:       
        os.makedirs(path)
        print('Done Path')
    else:        
        print( path + ' is exist')

# %%
'''
Timeslot=200
Carrier_bandwidth=200
Num_of_UE=20
Demand=50
Num_of_macro=0
Num_of_micro=7
Time=900
'''
################################## set device ##################################

print("============================================================================================")


# set device to cpu or cuda
ppo_device = torch.device('cpu')

if(torch.cuda.is_available()): 
    ppo_device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(ppo_device)))
else:
    print("Device set to : cpu")
    
print("============================================================================================")

'''
cell_num=7
K_epochs = 15               # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
gamma = 0.99                 # discount factor
lr_model = 0.001       # learning rate for actor network
lr_critic = 0.002       # learning rate for critic network
max_len=3               # max output length
embbeding_dim=24        # embbeding dimension
batch_size = 2048
t_agent = Transformer_PPO.PPO( cell_num, lr_model, lr_critic, gamma, K_epochs, eps_clip, 
                              max_len,ppo_device
                              , embbeding_dim)
'''
'''
Num_of_UE=100
Demand=20
'''


Num_of_st=298
Num_of_UE=40
Demand=50
#119+18 = 137
#168+18
#70+18
#200+11+3+11
#100+21+3+21+1
#[cover, load, v_time, action space]
state_dim = Num_of_st*3+Num_of_st
action_dim = 22
lr_actor = 0.001
lr_critic = 0.001
#gamma = 0.9
gamma = 0
K_epochs = 100
has_continuous_action_space=False
eps_clip = 0.2 
action_std = 0.6  
device = ppo_device
test = False
time_step = 0
re_mean =0
re_std =0

t_agent = PPO_A2C_SEQ.PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, 
                K_epochs, eps_clip, has_continuous_action_space, action_std, \
                           device, test, time_step, re_mean, re_std, num_ue =Num_of_UE  )
# Out:
# ============================================================================================
# Device set to : NVIDIA GeForce RTX 3060
# ============================================================================================

# %%
################### checkpointing ###################
run_num_pretrained=1

directory = "PPO_preTrained"
if not os.path.exists(directory):
      os.makedirs(directory)
em = 'Eichstatt'
algo = 'PPO_TF'
case = 'Result'
env_name=em+'_'+algo+'_'+case
directory = directory + '/' + env_name + '/'
if not os.path.exists(directory):
      os.makedirs(directory)


checkpoint_path = directory + "PPO_{}_{}.pth".format(env_name, run_num_pretrained)
print("save checkpoint path : " + checkpoint_path)
#reward_table_checkpoint_path=directory + "reward_table{}_{}.pth".format(env_name, run_num_pretrained)
#print("save reward_table checkpoint path : " + reward_table_checkpoint_path)

#critic_checkpoint_path=directory + "critic_{}_{}.pth".format(env_name, run_num_pretrained)
#print("save critic checkpoint path : " + critic_checkpoint_path)
# Out:
# save checkpoint path : PPO_preTrained/Eichstatt_PPO_TF_Result/PPO_Eichstatt_PPO_TF_Result_1.pth

# %%
Timeslot=1000
Carrier_bandwidth=200
Time=3600
#Time=1000
power = 35
Num_of_UE=1
s= 3
num_of_channel =5
e_greedy =0.30
#e_greedy =0
# training part
time_step=0
max_training_timesteps=0
update_timestep=1
save_model_freq=1


start_time = datetime.datetime.now().replace(microsecond=0)


qv =[]

print("Started training at (GMT) : ", start_time)

print("============================================================================================")
#load checkpoint
if(os.path.exists(checkpoint_path)):
    t_agent.load(checkpoint_path)
    #t_agent.load(checkpoint_path,reward_table_checkpoint_path,critic_checkpoint_path)
#
Rand = 1

while time_step <= max_training_timesteps:
    #Rand = random.randint(1,10)    
    print('random'+str(Rand))
    Dual_Connect.sim(algo=PPO_TF_HO_Algo,algo_name='PPO_TF_HO_Algo',timeslot=Timeslot,\
                    carrier_bandwidth=Carrier_bandwidth,
                    num_of_UE=Num_of_UE,demand=Demand,num_of_st=Num_of_st,\
                    time=Time, RL_Agent=t_agent, time_step = time_step, power = power,\
                    time_th=max_training_timesteps/2, R =Rand, strategy=s, Per=num_of_channel,E= e_greedy)
    

    
    
    time_step +=1
    t_agent.time_step = time_step
    '''
    #qv.append(fq)
    
    print('time_step:' +str(t_agent.time_step ))
    
    
    if time_step>0 and time_step % update_timestep == 0:
        print('Updating...')
        #t_agent.update()
    if (time_step>0 and time_step% save_model_freq) == 0:
        print("--------------------------------------------------------------------------------------------")
        print("saving model at : " + checkpoint_path)
        t_agent.save(checkpoint_path)
        
        #print("saving model at : " + 
        #      checkpoint_path, reward_table_checkpoint_path, critic_checkpoint_path)
        #t_agent.save(checkpoint_path, reward_table_checkpoint_path, critic_checkpoint_path)
        print("model saved")
        print("Elapsed Time  : ", datetime.datetime.now().replace(microsecond=0) - start_time)
        print("--------------------------------------------------------------------------------------------")
    '''
# Out:
# Started training at (GMT) :  2023-10-17 14:01:59
# ============================================================================================
# random1
# sim time step: 0
# st: 30
# tensor([-190.1192], device='cuda:0')
# st: 66
# tensor([-164.6036], device='cuda:0')
# st: 180
# tensor([-193.8041], device='cuda:0')
# st: 191
# tensor([-190.8493], device='cuda:0')
# st: 202
# tensor([-178.2354], device='cuda:0')
# st: 212
# tensor([-191.5727], device='cuda:0')
# st: 223
# tensor([-188.3550], device='cuda:0')
# st: 233
# tensor([-177.1853], device='cuda:0')
# st: 234
# tensor([-162.1785], device='cuda:0')
# st: 244
# tensor([-194.4573], device='cuda:0')
# st: 255
# tensor([-163.5760], device='cuda:0')
# st: 30
# tensor([-192.5559], device='cuda:0')
# st: 66
# tensor([-165.7202], device='cuda:0')
# st: 180
# tensor([-196.1953], device='cuda:0')
# st: 191
# tensor([-193.2010], device='cuda:0')
# st: 202
# tensor([-180.5451], device='cuda:0')
# st: 212
# tensor([-193.8081], device='cuda:0')
# st: 223
# tensor([-190.6351], device='cuda:0')
# st: 233
# tensor([-178.2257], device='cuda:0')
# st: 234
# tensor([-162.5460], device='cuda:0')
# st: 244
# tensor([-196.5384], device='cuda:0')
# st: 255
# tensor([-164.6376], device='cuda:0')
# st: 30
# tensor([-194.9270], device='cuda:0')
# st: 66
# tensor([-167.8307], device='cuda:0')
# st: 180
# tensor([-198.4739], device='cuda:0')
# st: 191
# tensor([-195.4298], device='cuda:0')
# st: 202
# tensor([-182.9441], device='cuda:0')
# st: 212
# tensor([-196.3513], device='cuda:0')
# st: 223
# tensor([-193.0164], device='cuda:0')
# st: 233
# tensor([-180.5533], device='cuda:0')
# st: 234
# tensor([-163.7405], device='cuda:0')
# st: 244
# tensor([-199.0896], device='cuda:0')
# st: 255
# tensor([-166.6105], device='cuda:0')
# st: 30
# tensor([-197.2569], device='cuda:0')
# st: 66
# tensor([-170.2282], device='cuda:0')
# st: 180
# tensor([-200.7849], device='cuda:0')
# st: 191
# tensor([-197.8525], device='cuda:0')
# st: 202
# tensor([-185.3505], device='cuda:0')
# st: 212
# tensor([-198.6208], device='cuda:0')
# st: 223
# tensor([-195.4357], device='cuda:0')
# st: 233
# tensor([-183.0231], device='cuda:0')
# st: 234
# tensor([-165.8570], device='cuda:0')
# st: 244
# tensor([-201.3170], device='cuda:0')
# st: 255
# tensor([-169.0648], device='cuda:0')
# st: 30
# tensor([-199.5646], device='cuda:0')
# st: 66
# tensor([-172.5354], device='cuda:0')
# st: 180
# tensor([-203.1762], device='cuda:0')
# st: 191
# tensor([-199.7506], device='cuda:0')
# st: 202
# tensor([-187.6332], device='cuda:0')
# st: 212
# tensor([-200.9175], device='cuda:0')
# st: 223
# tensor([-197.5024], device='cuda:0')
# st: 233
# tensor([-185.3017], device='cuda:0')
# st: 234
# tensor([-168.1680], device='cuda:0')
# st: 244
# tensor([-203.3842], device='cuda:0')
# st: 255
# tensor([-171.4228], device='cuda:0')
# st: 30
# tensor([-201.7142], device='cuda:0')
# st: 66
# tensor([-174.9801], device='cuda:0')
# st: 180
# tensor([-205.1879], device='cuda:0')
# st: 191
# tensor([-201.8426], device='cuda:0')
# st: 202
# tensor([-189.9834], device='cuda:0')
# st: 212
# tensor([-202.9977], device='cuda:0')
# st: 223
# tensor([-199.6049], device='cuda:0')
# st: 233
# tensor([-187.6887], device='cuda:0')
# st: 234
# tensor([-170.5723], device='cuda:0')
# st: 244
# tensor([-205.3762], device='cuda:0')
# st: 255
# tensor([-173.7006], device='cuda:0')
# st: 30
# tensor([-203.7534], device='cuda:0')
# st: 66
# tensor([-177.4655], device='cuda:0')
# st: 180
# tensor([-207.0941], device='cuda:0')
# st: 191
# tensor([-203.9104], device='cuda:0')
# st: 202
# tensor([-191.8405], device='cuda:0')
# st: 212
# tensor([-205.0716], device='cuda:0')
# st: 223
# tensor([-201.6838], device='cuda:0')
# st: 233
# tensor([-190.1347], device='cuda:0')
# st: 234
# tensor([-173.0681], device='cuda:0')
# st: 244
# tensor([-207.4447], device='cuda:0')
# st: 255
# tensor([-176.1510], device='cuda:0')
# st: 30
# tensor([-205.7371], device='cuda:0')
# st: 66
# tensor([-179.5374], device='cuda:0')
# st: 180
# tensor([-209.1633], device='cuda:0')
# st: 191
# tensor([-205.9926], device='cuda:0')
# st: 202
# tensor([-193.9255], device='cuda:0')
# st: 212
# tensor([-207.1542], device='cuda:0')
# st: 223
# tensor([-203.7182], device='cuda:0')
# st: 233
# tensor([-192.3712], device='cuda:0')
# st: 234
# tensor([-175.3642], device='cuda:0')
# st: 244
# tensor([-209.5461], device='cuda:0')
# st: 255
# tensor([-178.3779], device='cuda:0')
# st: 30
# tensor([-207.8089], device='cuda:0')
# st: 66
# tensor([-181.5742], device='cuda:0')
# st: 180
# tensor([-211.2461], device='cuda:0')
# st: 191
# tensor([-207.9583], device='cuda:0')
# st: 202
# tensor([-195.9717], device='cuda:0')
# st: 212
# tensor([-209.2415], device='cuda:0')
# st: 223
# tensor([-205.5782], device='cuda:0')
# st: 233
# tensor([-194.4288], device='cuda:0')
# st: 234
# tensor([-177.4218], device='cuda:0')
# st: 244
# tensor([-211.5676], device='cuda:0')
# st: 255
# tensor([-180.3284], device='cuda:0')
# st: 30
# tensor([-209.7330], device='cuda:0')
# st: 66
# tensor([-183.7011], device='cuda:0')
# st: 180
# tensor([-213.3468], device='cuda:0')
# st: 191
# tensor([-210.0740], device='cuda:0')
# st: 202
# tensor([-197.8833], device='cuda:0')
# st: 212
# tensor([-211.1691], device='cuda:0')
# st: 223
# tensor([-207.6566], device='cuda:0')
# st: 233
# tensor([-196.3697], device='cuda:0')
# st: 234
# tensor([-179.4466], device='cuda:0')
# st: 244
# tensor([-213.6274], device='cuda:0')
# st: 255
# tensor([-182.4908], device='cuda:0')
# st: 30
# tensor([-211.9708], device='cuda:0')
# st: 66
# tensor([-185.6390], device='cuda:0')
# st: 180
# tensor([-215.4268], device='cuda:0')
# st: 191
# tensor([-211.8913], device='cuda:0')
# st: 202
# tensor([-200.0067], device='cuda:0')
# st: 212
# tensor([-213.3433], device='cuda:0')
# st: 223
# tensor([-209.8142], device='cuda:0')
# st: 233
# tensor([-198.3620], device='cuda:0')
# st: 234
# tensor([-181.7180], device='cuda:0')
# st: 244
# tensor([-215.7140], device='cuda:0')
# st: 255
# tensor([-184.4406], device='cuda:0')
# st: 30
# tensor([-213.9817], device='cuda:0')
# st: 66
# tensor([-187.8533], device='cuda:0')
# st: 180
# tensor([-217.4328], device='cuda:0')
# st: 191
# tensor([-214.0646], device='cuda:0')
# st: 202
# tensor([-202.0452], device='cuda:0')
# st: 212
# tensor([-215.2501], device='cuda:0')
# st: 223
# tensor([-211.8889], device='cuda:0')
# st: 233
# tensor([-200.7139], device='cuda:0')
# st: 234
# tensor([-183.6877], device='cuda:0')
# st: 244
# tensor([-217.6568], device='cuda:0')
# st: 255
# tensor([-186.4551], device='cuda:0')
# st: 30
# tensor([-216.0603], device='cuda:0')
# st: 66
# tensor([-189.7037], device='cuda:0')
# st: 180
# tensor([-219.4556], device='cuda:0')
# st: 191
# tensor([-216.0982], device='cuda:0')
# st: 202
# tensor([-204.1108], device='cuda:0')
# st: 212
# tensor([-217.5024], device='cuda:0')
# st: 223
# tensor([-213.7553], device='cuda:0')
# st: 233
# tensor([-202.9244], device='cuda:0')
# st: 234
# tensor([-185.6753], device='cuda:0')
# st: 244
# tensor([-219.8394], device='cuda:0')
# st: 255
# tensor([-188.6052], device='cuda:0')
# st: 30
# tensor([-217.9902], device='cuda:0')
# st: 66
# tensor([-191.8696], device='cuda:0')
# st: 180
# tensor([-221.4370], device='cuda:0')
# st: 191
# tensor([-217.9948], device='cuda:0')
# st: 202
# tensor([-206.0922], device='cuda:0')
# st: 212
# tensor([-219.5161], device='cuda:0')
# st: 223
# tensor([-215.7605], device='cuda:0')
# st: 233
# tensor([-205.1013], device='cuda:0')
# st: 234
# tensor([-187.6864], device='cuda:0')
# st: 244
# tensor([-221.9009], device='cuda:0')
# st: 255
# tensor([-190.5428], device='cuda:0')
# st: 30
# tensor([-220.1427], device='cuda:0')
# st: 66
# tensor([-193.7511], device='cuda:0')
# st: 180
# tensor([-223.5218], device='cuda:0')
# st: 191
# tensor([-220.2025], device='cuda:0')
# st: 202
# tensor([-208.0899], device='cuda:0')
# st: 212
# tensor([-221.7742], device='cuda:0')
# st: 223
# tensor([-217.7817], device='cuda:0')
# st: 233
# tensor([-207.1447], device='cuda:0')
# st: 234
# tensor([-189.6797], device='cuda:0')
# st: 244
# tensor([-223.9203], device='cuda:0')
# st: 255
# tensor([-192.6391], device='cuda:0')
# st: 30
# tensor([-222.2326], device='cuda:0')
# st: 66
# tensor([-195.9292], device='cuda:0')
# st: 180
# tensor([-225.6961], device='cuda:0')
# st: 191
# tensor([-222.1073], device='cuda:0')
# st: 202
# tensor([-210.2541], device='cuda:0')
# st: 212
# tensor([-224.3763], device='cuda:0')
# st: 223
# tensor([-220.0398], device='cuda:0')
# st: 233
# tensor([-209.2688], device='cuda:0')
# st: 234
# tensor([-191.7508], device='cuda:0')
# st: 244
# tensor([-225.9864], device='cuda:0')
# st: 255
# tensor([-194.5630], device='cuda:0')
# st: 30
# tensor([-224.6163], device='cuda:0')
# st: 66
# tensor([-197.9531], device='cuda:0')
# st: 180
# tensor([-227.7795], device='cuda:0')
# st: 191
# tensor([-224.3913], device='cuda:0')
# st: 202
# tensor([-212.2111], device='cuda:0')
# st: 212
# tensor([-226.6629], device='cuda:0')
# st: 223
# tensor([-221.9998], device='cuda:0')
# st: 233
# tensor([-211.7450], device='cuda:0')
# st: 234
# tensor([-194.0002], device='cuda:0')
# st: 244
# tensor([-228.1259], device='cuda:0')
# st: 255
# tensor([-196.6004], device='cuda:0')
# st: 30
# tensor([-226.7364], device='cuda:0')
# st: 66
# tensor([-200.2427], device='cuda:0')
# st: 180
# tensor([-230.3844], device='cuda:0')
# st: 191
# tensor([-226.5432], device='cuda:0')
# st: 202
# tensor([-214.4389], device='cuda:0')
# st: 212
# tensor([-229.1049], device='cuda:0')
# st: 223
# tensor([-224.0302], device='cuda:0')
# st: 233
# tensor([-213.9514], device='cuda:0')
# st: 234
# tensor([-196.1764], device='cuda:0')
# st: 244
# tensor([-230.6360], device='cuda:0')
# st: 255
# tensor([-198.9666], device='cuda:0')
# st: 30
# tensor([-228.9620], device='cuda:0')
# st: 66
# tensor([-202.4597], device='cuda:0')
# st: 180
# tensor([-232.8731], device='cuda:0')
# st: 191
# tensor([-228.5214], device='cuda:0')
# st: 202
# tensor([-216.5253], device='cuda:0')
# st: 212
# tensor([-231.3219], device='cuda:0')
# st: 223
# tensor([-225.9792], device='cuda:0')
# st: 233
# tensor([-216.1075], device='cuda:0')
# st: 234
# tensor([-198.2115], device='cuda:0')
# st: 244
# tensor([-232.7797], device='cuda:0')
# st: 255
# tensor([-201.0149], device='cuda:0')
# st: 30
# tensor([-231.0800], device='cuda:0')
# st: 66
# tensor([-204.4975], device='cuda:0')
# st: 180
# tensor([-235.0284], device='cuda:0')
# st: 191
# tensor([-230.7487], device='cuda:0')
# st: 202
# tensor([-218.7247], device='cuda:0')
# st: 212
# tensor([-233.4261], device='cuda:0')
# st: 223
# tensor([-228.1889], device='cuda:0')
# st: 233
# tensor([-218.2149], device='cuda:0')
# st: 234
# tensor([-200.4132], device='cuda:0')
# st: 244
# tensor([-234.8866], device='cuda:0')
# st: 255
# tensor([-203.2036], device='cuda:0')
# st: 30
# tensor([-233.2993], device='cuda:0')
# st: 66
# tensor([-206.5406], device='cuda:0')
# st: 180
# tensor([-237.4188], device='cuda:0')
# st: 191
# tensor([-232.8336], device='cuda:0')
# st: 202
# tensor([-220.9636], device='cuda:0')
# st: 212
# tensor([-235.5922], device='cuda:0')
# st: 223
# tensor([-230.4861], device='cuda:0')
# st: 233
# tensor([-220.4164], device='cuda:0')
# st: 234
# tensor([-202.7875], device='cuda:0')
# st: 244
# tensor([-237.0695], device='cuda:0')
# st: 255
# tensor([-205.3804], device='cuda:0')
# st: 30
# tensor([-235.5017], device='cuda:0')
# st: 66
# tensor([-208.8584], device='cuda:0')
# st: 180
# tensor([-239.5535], device='cuda:0')
# st: 191
# tensor([-235.1907], device='cuda:0')
# st: 202
# tensor([-223.1475], device='cuda:0')
# st: 212
# tensor([-237.5951], device='cuda:0')
# st: 223
# tensor([-232.7214], device='cuda:0')
# st: 233
# tensor([-222.4641], device='cuda:0')
# st: 234
# tensor([-204.7416], device='cuda:0')
# st: 244
# tensor([-239.2571], device='cuda:0')
# st: 255
# tensor([-207.4786], device='cuda:0')
# st: 30
# tensor([-237.6227], device='cuda:0')
# st: 66
# tensor([-210.7348], device='cuda:0')
# st: 180
# tensor([-241.6232], device='cuda:0')
# st: 191
# tensor([-237.3001], device='cuda:0')
# st: 202
# tensor([-225.1515], device='cuda:0')
# st: 212
# tensor([-239.9750], device='cuda:0')
# st: 223
# tensor([-234.7238], device='cuda:0')
# st: 233
# tensor([-224.5046], device='cuda:0')
# st: 234
# tensor([-206.5811], device='cuda:0')
# st: 244
# tensor([-241.5298], device='cuda:0')
# st: 255
# tensor([-209.5309], device='cuda:0')
# st: 30
# tensor([-239.7529], device='cuda:0')
# st: 66
# tensor([-212.5740], device='cuda:0')
# st: 180
# tensor([-243.7590], device='cuda:0')
# st: 191
# tensor([-239.5187], device='cuda:0')
# st: 202
# tensor([-227.2130], device='cuda:0')
# st: 212
# tensor([-242.0270], device='cuda:0')
# st: 223
# tensor([-236.9147], device='cuda:0')
# st: 233
# tensor([-226.2838], device='cuda:0')
# st: 234
# tensor([-208.2376], device='cuda:0')
# st: 244
# tensor([-243.7235], device='cuda:0')
# st: 255
# tensor([-211.1139], device='cuda:0')
# st: 30
# tensor([-241.7885], device='cuda:0')
# st: 66
# tensor([-214.1017], device='cuda:0')
# st: 180
# tensor([-245.9462], device='cuda:0')
# st: 191
# tensor([-241.4432], device='cuda:0')
# st: 202
# tensor([-229.0845], device='cuda:0')
# st: 212
# tensor([-244.0616], device='cuda:0')
# st: 223
# tensor([-238.9633], device='cuda:0')
# st: 233
# tensor([-227.9594], device='cuda:0')
# st: 234
# tensor([-209.8186], device='cuda:0')
# st: 244
# tensor([-245.6778], device='cuda:0')
# st: 255
# tensor([-212.8286], device='cuda:0')
# st: 30
# tensor([-243.9609], device='cuda:0')
# st: 66
# tensor([-215.5644], device='cuda:0')
# st: 180
# tensor([-248.0581], device='cuda:0')
# st: 191
# tensor([-243.4214], device='cuda:0')
# st: 202
# tensor([-231.2907], device='cuda:0')
# st: 212
# tensor([-245.9832], device='cuda:0')
# st: 223
# tensor([-241.0916], device='cuda:0')
# st: 233
# tensor([-229.6188], device='cuda:0')
# st: 234
# tensor([-211.3961], device='cuda:0')
# st: 244
# tensor([-247.6776], device='cuda:0')
# st: 255
# tensor([-214.1467], device='cuda:0')
# st: 30
# tensor([-245.8101], device='cuda:0')
# st: 66
# tensor([-217.3019], device='cuda:0')
# st: 180
# tensor([-249.9751], device='cuda:0')
# st: 191
# tensor([-245.5152], device='cuda:0')
# st: 202
# tensor([-232.9166], device='cuda:0')
# st: 212
# tensor([-247.9987], device='cuda:0')
# st: 223
# tensor([-243.0606], device='cuda:0')
# st: 233
# tensor([-231.2206], device='cuda:0')
# st: 234
# tensor([-212.7830], device='cuda:0')
# st: 244
# tensor([-249.6988], device='cuda:0')
# st: 255
# tensor([-215.5521], device='cuda:0')
# st: 30
# tensor([-247.8118], device='cuda:0')
# st: 66
# tensor([-218.5791], device='cuda:0')
# st: 180
# tensor([-251.9668], device='cuda:0')
# st: 191
# tensor([-247.4396], device='cuda:0')
# st: 202
# tensor([-234.7088], device='cuda:0')
# st: 212
# tensor([-250.0860], device='cuda:0')
# st: 223
# tensor([-245.1062], device='cuda:0')
# st: 233
# tensor([-232.6359], device='cuda:0')
# st: 234
# tensor([-214.3591], device='cuda:0')
# st: 244
# tensor([-251.7747], device='cuda:0')
# st: 255
# tensor([-217.2830], device='cuda:0')
# st: 30
# tensor([-249.6757], device='cuda:0')
# st: 66
# tensor([-220.2486], device='cuda:0')
# st: 180
# tensor([-254.0372], device='cuda:0')
# st: 191
# tensor([-249.2823], device='cuda:0')
# st: 202
# tensor([-236.2599], device='cuda:0')
# st: 212
# tensor([-251.9690], device='cuda:0')
# st: 223
# tensor([-247.0081], device='cuda:0')
# st: 233
# tensor([-234.2527], device='cuda:0')
# st: 234
# tensor([-215.7412], device='cuda:0')
# st: 244
# tensor([-253.8381], device='cuda:0')
# st: 255
# tensor([-218.8028], device='cuda:0')
# st: 30
# tensor([-251.6075], device='cuda:0')
# st: 66
# tensor([-221.6228], device='cuda:0')
# st: 180
# tensor([-255.9531], device='cuda:0')
# st: 191
# tensor([-251.1802], device='cuda:0')
# st: 202
# tensor([-237.6673], device='cuda:0')
# st: 212
# tensor([-253.9789], device='cuda:0')
# st: 223
# tensor([-248.7807], device='cuda:0')
# st: 233
# tensor([-235.5461], device='cuda:0')
# st: 234
# tensor([-217.1318], device='cuda:0')
# st: 244
# tensor([-255.7076], device='cuda:0')
# st: 255
# tensor([-220.1975], device='cuda:0')
# st: 30
# tensor([-253.6461], device='cuda:0')
# st: 66
# tensor([-223.0417], device='cuda:0')
# st: 180
# tensor([-258.0165], device='cuda:0')
# st: 191
# tensor([-252.8370], device='cuda:0')
# st: 202
# tensor([-239.4869], device='cuda:0')
# st: 212
# tensor([-255.7537], device='cuda:0')
# st: 223
# tensor([-250.7405], device='cuda:0')
# st: 233
# tensor([-236.9238], device='cuda:0')
# st: 234
# tensor([-218.8437], device='cuda:0')
# st: 244
# tensor([-257.6693], device='cuda:0')
# st: 255
# tensor([-221.7287], device='cuda:0')
# st: 30
# tensor([-255.3761], device='cuda:0')
# st: 66
# tensor([-224.8615], device='cuda:0')
# st: 180
# tensor([-259.8668], device='cuda:0')
# st: 191
# tensor([-254.6699], device='cuda:0')
# st: 202
# tensor([-240.7964], device='cuda:0')
# st: 212
# tensor([-257.4542], device='cuda:0')
# st: 223
# tensor([-252.4379], device='cuda:0')
# st: 233
# tensor([-238.6733], device='cuda:0')
# st: 234
# tensor([-220.2209], device='cuda:0')
# st: 244
# tensor([-259.3000], device='cuda:0')
# st: 255
# tensor([-223.0379], device='cuda:0')
# st: 30
# tensor([-257.0167], device='cuda:0')
# st: 66
# tensor([-226.0562], device='cuda:0')
# st: 180
# tensor([-261.5979], device='cuda:0')
# st: 191
# tensor([-256.4922], device='cuda:0')
# st: 202
# tensor([-242.3263], device='cuda:0')
# st: 212
# tensor([-259.3406], device='cuda:0')
# st: 223
# tensor([-254.2142], device='cuda:0')
# st: 233
# tensor([-240.1600], device='cuda:0')
# st: 234
# tensor([-221.8266], device='cuda:0')
# st: 244
# tensor([-261.2017], device='cuda:0')
# st: 255
# tensor([-224.8559], device='cuda:0')
# st: 30
# tensor([-258.4777], device='cuda:0')
# st: 66
# tensor([-227.4993], device='cuda:0')
# st: 180
# tensor([-263.3471], device='cuda:0')
# st: 191
# tensor([-257.9818], device='cuda:0')
# st: 202
# tensor([-243.7875], device='cuda:0')
# st: 212
# tensor([-260.6611], device='cuda:0')
# st: 223
# tensor([-255.6725], device='cuda:0')
# st: 233
# tensor([-241.6334], device='cuda:0')
# st: 234
# tensor([-223.1473], device='cuda:0')
# st: 244
# tensor([-262.8629], device='cuda:0')
# st: 255
# tensor([-226.1188], device='cuda:0')
# st: 30
# tensor([-260.0056], device='cuda:0')
# st: 66
# tensor([-229.1066], device='cuda:0')
# st: 180
# tensor([-265.1860], device='cuda:0')
# st: 191
# tensor([-259.3440], device='cuda:0')
# st: 202
# tensor([-245.1711], device='cuda:0')
# st: 212
# tensor([-262.3145], device='cuda:0')
# st: 223
# tensor([-257.2633], device='cuda:0')
# st: 233
# tensor([-243.0970], device='cuda:0')
# st: 234
# tensor([-224.5558], device='cuda:0')
# st: 244
# tensor([-264.4354], device='cuda:0')
# st: 255
# tensor([-227.5589], device='cuda:0')
# st: 30
# tensor([-261.0864], device='cuda:0')
# st: 66
# tensor([-230.1508], device='cuda:0')
# st: 180
# tensor([-266.4460], device='cuda:0')
# st: 191
# tensor([-260.5109], device='cuda:0')
# st: 202
# tensor([-246.2929], device='cuda:0')
# st: 212
# tensor([-263.1535], device='cuda:0')
# st: 223
# tensor([-258.2070], device='cuda:0')
# st: 233
# tensor([-244.1391], device='cuda:0')
# st: 244
# tensor([-265.4053], device='cuda:0')
# st: 255
# tensor([-228.5069], device='cuda:0')
# st: 30
# tensor([-262.3671], device='cuda:0')
# st: 66
# tensor([-231.5036], device='cuda:0')
# st: 180
# tensor([-267.5598], device='cuda:0')
# st: 191
# tensor([-261.6974], device='cuda:0')
# st: 202
# tensor([-247.5359], device='cuda:0')
# st: 212
# tensor([-264.7062], device='cuda:0')
# st: 223
# tensor([-259.5491], device='cuda:0')
# st: 233
# tensor([-245.3532], device='cuda:0')
# st: 244
# tensor([-266.7949], device='cuda:0')
# st: 255
# tensor([-229.9399], device='cuda:0')
# st: 30
# tensor([-263.1253], device='cuda:0')
# st: 66
# tensor([-232.2574], device='cuda:0')
# st: 180
# tensor([-268.5317], device='cuda:0')
# st: 191
# tensor([-262.4295], device='cuda:0')
# st: 202
# tensor([-248.5191], device='cuda:0')
# st: 212
# tensor([-265.4071], device='cuda:0')
# st: 223
# tensor([-260.3967], device='cuda:0')
# st: 233
# tensor([-246.1962], device='cuda:0')
# st: 244
# tensor([-267.5331], device='cuda:0')
# st: 255
# tensor([-230.8654], device='cuda:0')
# st: 30
# tensor([-264.0575], device='cuda:0')
# st: 66
# tensor([-233.2431], device='cuda:0')
# st: 180
# tensor([-269.4053], device='cuda:0')
# st: 191
# tensor([-263.4893], device='cuda:0')
# st: 202
# tensor([-249.3046], device='cuda:0')
# st: 212
# tensor([-266.2699], device='cuda:0')
# st: 223
# tensor([-261.3587], device='cuda:0')
# st: 233
# tensor([-247.1479], device='cuda:0')
# st: 244
# tensor([-268.3082], device='cuda:0')
# st: 255
# tensor([-231.6316], device='cuda:0')
# st: 30
# tensor([-264.9190], device='cuda:0')
# st: 66
# tensor([-233.9742], device='cuda:0')
# st: 180
# tensor([-270.2721], device='cuda:0')
# st: 191
# tensor([-264.2572], device='cuda:0')
# st: 202
# tensor([-250.2404], device='cuda:0')
# st: 212
# tensor([-267.2220], device='cuda:0')
# st: 223
# tensor([-262.0421], device='cuda:0')
# st: 233
# tensor([-247.9134], device='cuda:0')
# st: 244
# tensor([-269.4157], device='cuda:0')
# st: 255
# tensor([-232.6629], device='cuda:0')
# st: 30
# tensor([-265.7350], device='cuda:0')
# st: 66
# tensor([-234.6709], device='cuda:0')
# st: 180
# tensor([-271.2534], device='cuda:0')
# st: 191
# tensor([-265.1032], device='cuda:0')
# st: 202
# tensor([-251.1928], device='cuda:0')
# st: 212
# tensor([-267.9842], device='cuda:0')
# st: 223
# tensor([-263.1583], device='cuda:0')
# st: 233
# tensor([-248.7183], device='cuda:0')
# st: 244
# tensor([-270.3365], device='cuda:0')
# st: 255
# tensor([-233.4584], device='cuda:0')
# st: 30
# tensor([-266.6946], device='cuda:0')
# st: 66
# tensor([-235.7671], device='cuda:0')
# st: 180
# tensor([-271.9662], device='cuda:0')
# st: 191
# tensor([-266.0882], device='cuda:0')
# st: 202
# tensor([-251.9009], device='cuda:0')
# st: 212
# tensor([-268.9082], device='cuda:0')
# st: 223
# tensor([-263.9277], device='cuda:0')
# st: 233
# tensor([-249.6598], device='cuda:0')
# st: 244
# tensor([-271.2221], device='cuda:0')
# st: 255
# tensor([-234.4523], device='cuda:0')
# st: 30
# tensor([-267.6823], device='cuda:0')
# st: 66
# tensor([-236.5846], device='cuda:0')
# st: 180
# tensor([-272.9556], device='cuda:0')
# st: 191
# tensor([-266.9420], device='cuda:0')
# st: 202
# tensor([-252.8419], device='cuda:0')
# st: 212
# tensor([-269.8985], device='cuda:0')
# st: 223
# tensor([-264.7153], device='cuda:0')
# st: 233
# tensor([-250.4986], device='cuda:0')
# st: 244
# tensor([-272.0262], device='cuda:0')
# st: 255
# tensor([-235.1099], device='cuda:0')
# st: 30
# tensor([-268.5921], device='cuda:0')
# st: 66
# tensor([-237.6230], device='cuda:0')
# st: 180
# tensor([-273.7367], device='cuda:0')
# st: 191
# tensor([-267.8848], device='cuda:0')
# st: 202
# tensor([-253.7592], device='cuda:0')
# st: 212
# tensor([-270.7061], device='cuda:0')
# st: 223
# tensor([-265.6877], device='cuda:0')
# st: 233
# tensor([-251.4636], device='cuda:0')
# st: 244
# tensor([-272.8280], device='cuda:0')
# st: 255
# tensor([-236.0169], device='cuda:0')
# st: 30
# tensor([-269.3680], device='cuda:0')
# st: 66
# tensor([-238.4019], device='cuda:0')
# st: 180
# tensor([-274.5989], device='cuda:0')
# st: 191
# tensor([-268.7104], device='cuda:0')
# st: 202
# tensor([-254.4857], device='cuda:0')
# st: 212
# tensor([-271.5613], device='cuda:0')
# st: 223
# tensor([-266.4998], device='cuda:0')
# st: 233
# tensor([-252.2438], device='cuda:0')
# st: 244
# tensor([-273.7091], device='cuda:0')
# st: 255
# tensor([-236.9492], device='cuda:0')
# st: 30
# tensor([-270.3007], device='cuda:0')
# st: 66
# tensor([-239.2298], device='cuda:0')
# st: 180
# tensor([-275.7084], device='cuda:0')
# st: 191
# tensor([-269.5793], device='cuda:0')
# st: 202
# tensor([-255.6354], device='cuda:0')
# st: 212
# tensor([-272.3792], device='cuda:0')
# st: 223
# tensor([-267.3823], device='cuda:0')
# st: 233
# tensor([-253.0190], device='cuda:0')
# st: 244
# tensor([-274.7761], device='cuda:0')
# st: 255
# tensor([-237.7791], device='cuda:0')
# st: 30
# tensor([-271.0567], device='cuda:0')
# st: 66
# tensor([-240.1498], device='cuda:0')
# st: 180
# tensor([-276.2635], device='cuda:0')
# st: 191
# tensor([-270.4181], device='cuda:0')
# st: 202
# tensor([-256.4375], device='cuda:0')
# st: 212
# tensor([-273.4477], device='cuda:0')
# st: 223
# tensor([-268.3980], device='cuda:0')
# st: 233
# tensor([-254.0186], device='cuda:0')
# st: 244
# tensor([-275.6226], device='cuda:0')
# st: 255
# tensor([-238.8564], device='cuda:0')
# st: 30
# tensor([-271.9033], device='cuda:0')
# st: 66
# tensor([-240.8833], device='cuda:0')
# st: 180
# tensor([-277.3886], device='cuda:0')
# st: 191
# tensor([-271.3887], device='cuda:0')
# st: 202
# tensor([-257.2192], device='cuda:0')
# st: 212
# tensor([-274.3144], device='cuda:0')
# st: 223
# tensor([-269.2729], device='cuda:0')
# st: 233
# tensor([-254.7164], device='cuda:0')
# st: 244
# tensor([-276.3818], device='cuda:0')
# st: 255
# tensor([-239.4807], device='cuda:0')
# st: 30
# tensor([-272.9464], device='cuda:0')
# st: 66
# tensor([-241.9051], device='cuda:0')
# st: 180
# tensor([-278.1801], device='cuda:0')
# st: 191
# tensor([-272.2806], device='cuda:0')
# st: 202
# tensor([-258.2151], device='cuda:0')
# st: 212
# tensor([-275.3872], device='cuda:0')
# st: 223
# tensor([-270.1033], device='cuda:0')
# st: 233
# tensor([-255.7763], device='cuda:0')
# st: 244
# tensor([-277.1945], device='cuda:0')
# st: 255
# tensor([-240.4886], device='cuda:0')
# st: 30
# tensor([-273.6897], device='cuda:0')
# st: 66
# tensor([-242.7040], device='cuda:0')
# st: 180
# tensor([-278.9746], device='cuda:0')
# st: 191
# tensor([-273.0849], device='cuda:0')
# st: 202
# tensor([-258.9143], device='cuda:0')
# st: 212
# tensor([-275.9480], device='cuda:0')
# st: 223
# tensor([-270.8475], device='cuda:0')
# st: 233
# tensor([-256.3711], device='cuda:0')
# st: 244
# tensor([-278.2825], device='cuda:0')
# st: 255
# tensor([-241.2552], device='cuda:0')
# st: 30
# tensor([-274.6142], device='cuda:0')
# st: 66
# tensor([-243.5196], device='cuda:0')
# st: 180
# tensor([-280.0269], device='cuda:0')
# st: 191
# tensor([-273.9313], device='cuda:0')
# st: 202
# tensor([-259.7697], device='cuda:0')
# st: 212
# tensor([-276.9219], device='cuda:0')
# st: 223
# tensor([-271.9534], device='cuda:0')
# st: 233
# tensor([-257.3304], device='cuda:0')
# st: 244
# tensor([-279.1223], device='cuda:0')
# st: 255
# tensor([-242.0986], device='cuda:0')
# st: 30
# tensor([-275.4092], device='cuda:0')
# st: 66
# tensor([-244.4137], device='cuda:0')
# st: 180
# tensor([-280.8919], device='cuda:0')
# st: 191
# tensor([-274.9373], device='cuda:0')
# st: 202
# tensor([-260.8446], device='cuda:0')
# st: 212
# tensor([-277.6922], device='cuda:0')
# st: 223
# tensor([-272.7995], device='cuda:0')
# st: 233
# tensor([-258.2373], device='cuda:0')
# st: 244
# tensor([-279.9763], device='cuda:0')
# st: 255
# tensor([-243.0988], device='cuda:0')
# st: 30
# tensor([-276.2082], device='cuda:0')
# st: 66
# tensor([-245.2708], device='cuda:0')
# st: 180
# tensor([-281.7602], device='cuda:0')
# st: 191
# tensor([-275.5762], device='cuda:0')
# st: 202
# tensor([-261.7025], device='cuda:0')
# st: 212
# tensor([-278.6158], device='cuda:0')
# st: 223
# tensor([-273.6792], device='cuda:0')
# st: 233
# tensor([-258.8781], device='cuda:0')
# st: 244
# tensor([-280.7886], device='cuda:0')
# st: 255
# tensor([-243.7553], device='cuda:0')
# st: 30
# tensor([-277.2859], device='cuda:0')
# st: 66
# tensor([-246.2439], device='cuda:0')
# st: 180
# tensor([-282.7650], device='cuda:0')
# st: 191
# tensor([-276.5995], device='cuda:0')
# st: 202
# tensor([-262.4737], device='cuda:0')
# st: 212
# tensor([-279.4537], device='cuda:0')
# st: 223
# tensor([-274.6777], device='cuda:0')
# st: 233
# tensor([-259.9042], device='cuda:0')
# st: 244
# tensor([-281.8508], device='cuda:0')
# st: 255
# tensor([-244.9503], device='cuda:0')
# st: 30
# tensor([-278.1344], device='cuda:0')
# st: 66
# tensor([-246.9832], device='cuda:0')
# st: 180
# tensor([-283.3846], device='cuda:0')
# st: 191
# tensor([-277.5248], device='cuda:0')
# st: 202
# tensor([-263.3099], device='cuda:0')
# st: 212
# tensor([-280.4891], device='cuda:0')
# st: 223
# tensor([-275.3612], device='cuda:0')
# st: 233
# tensor([-260.6208], device='cuda:0')
# st: 244
# tensor([-282.6996], device='cuda:0')
# st: 255
# tensor([-245.5914], device='cuda:0')
# st: 30
# tensor([-279.1927], device='cuda:0')
# st: 66
# tensor([-247.8455], device='cuda:0')
# st: 180
# tensor([-284.3831], device='cuda:0')
# st: 191
# tensor([-278.2741], device='cuda:0')
# st: 202
# tensor([-264.3420], device='cuda:0')
# st: 212
# tensor([-281.1232], device='cuda:0')
# st: 223
# tensor([-276.3752], device='cuda:0')
# st: 233
# tensor([-261.4692], device='cuda:0')
# st: 244
# tensor([-283.3975], device='cuda:0')
# st: 255
# tensor([-246.3728], device='cuda:0')
# st: 30
# tensor([-280.0486], device='cuda:0')
# st: 66
# tensor([-248.7246], device='cuda:0')
# st: 180
# tensor([-285.2278], device='cuda:0')
# st: 191
# tensor([-279.3242], device='cuda:0')
# st: 202
# tensor([-265.0902], device='cuda:0')
# st: 212
# tensor([-282.1255], device='cuda:0')
# st: 223
# tensor([-277.0440], device='cuda:0')
# st: 233
# tensor([-262.4657], device='cuda:0')
# st: 244
# tensor([-284.5982], device='cuda:0')
# st: 255
# tensor([-247.2756], device='cuda:0')
# st: 30
# tensor([-280.7469], device='cuda:0')
# st: 66
# tensor([-249.4124], device='cuda:0')
# st: 180
# tensor([-286.0426], device='cuda:0')
# st: 191
# tensor([-279.8900], device='cuda:0')
# st: 202
# tensor([-265.9939], device='cuda:0')
# st: 212
# tensor([-282.9152], device='cuda:0')
# st: 223
# tensor([-278.2039], device='cuda:0')
# st: 233
# tensor([-263.3166], device='cuda:0')
# st: 244
# tensor([-285.4259], device='cuda:0')
# st: 255
# tensor([-248.1134], device='cuda:0')
# st: 30
# tensor([-281.5621], device='cuda:0')
# st: 66
# tensor([-250.4902], device='cuda:0')
# st: 180
# tensor([-287.1322], device='cuda:0')
# st: 191
# tensor([-281.2419], device='cuda:0')
# st: 202
# tensor([-266.8679], device='cuda:0')
# st: 212
# tensor([-283.7977], device='cuda:0')
# st: 223
# tensor([-279.0443], device='cuda:0')
# st: 233
# tensor([-264.1292], device='cuda:0')
# st: 244
# tensor([-286.1869], device='cuda:0')
# st: 255
# tensor([-249.1158], device='cuda:0')
# st: 30
# tensor([658.9809], device='cuda:0')
# st: 66
# tensor([764.4324], device='cuda:0')
# st: 180
# tensor([650.0794], device='cuda:0')
# st: 191
# tensor([636.5911], device='cuda:0')
# st: 201
# tensor([924.8958], device='cuda:0')
# st: 202
# tensor([674.5927], device='cuda:0')
# st: 212
# tensor([675.3992], device='cuda:0')
# st: 223
# tensor([624.9359], device='cuda:0')
# st: 233
# tensor([811.4863], device='cuda:0')
# st: 244
# tensor([637.8260], device='cuda:0')
# st: 255
# tensor([760.9979], device='cuda:0')
# st: 30
# tensor([651.8668], device='cuda:0')
# st: 66
# tensor([756.8742], device='cuda:0')
# st: 180
# tensor([642.5881], device='cuda:0')
# st: 191
# tensor([628.5822], device='cuda:0')
# st: 201
# tensor([917.3804], device='cuda:0')
# st: 202
# tensor([667.7924], device='cuda:0')
# st: 212
# tensor([668.5118], device='cuda:0')
# st: 223
# tensor([618.2656], device='cuda:0')
# st: 233
# tensor([804.3309], device='cuda:0')
# st: 244
# tensor([630.8314], device='cuda:0')
# st: 255
# tensor([752.8242], device='cuda:0')
# st: 30
# tensor([647.1309], device='cuda:0')
# st: 66
# tensor([751.6006], device='cuda:0')
# st: 180
# tensor([636.7869], device='cuda:0')
# st: 191
# tensor([623.9835], device='cuda:0')
# st: 201
# tensor([911.9478], device='cuda:0')
# st: 202
# tensor([663.0273], device='cuda:0')
# st: 212
# tensor([663.9396], device='cuda:0')
# st: 223
# tensor([613.1900], device='cuda:0')
# st: 233
# tensor([798.2712], device='cuda:0')
# st: 244
# tensor([626.0078], device='cuda:0')
# st: 255
# tensor([747.2499], device='cuda:0')
# st: 30
# tensor([642.4028], device='cuda:0')
# st: 66
# tensor([746.0449], device='cuda:0')
# st: 180
# tensor([632.5371], device='cuda:0')
# st: 191
# tensor([619.1613], device='cuda:0')
# st: 201
# tensor([906.7780], device='cuda:0')
# st: 202
# tensor([658.0659], device='cuda:0')
# st: 212
# tensor([658.6160], device='cuda:0')
# st: 223
# tensor([608.6568], device='cuda:0')
# st: 233
# tensor([792.7680], device='cuda:0')
# st: 244
# tensor([621.2941], device='cuda:0')
# st: 255
# tensor([742.3303], device='cuda:0')
# st: 30
# tensor([637.6722], device='cuda:0')
# st: 66
# tensor([740.3575], device='cuda:0')
# st: 180
# tensor([627.4014], device='cuda:0')
# st: 191
# tensor([614.0180], device='cuda:0')
# st: 201
# tensor([901.4680], device='cuda:0')
# st: 202
# tensor([652.9296], device='cuda:0')
# st: 212
# tensor([653.8392], device='cuda:0')
# st: 223
# tensor([604.2744], device='cuda:0')
# st: 233
# tensor([787.1026], device='cuda:0')
# st: 244
# tensor([616.6221], device='cuda:0')
# st: 255
# tensor([737.6857], device='cuda:0')
# st: 30
# tensor([633.0668], device='cuda:0')
# st: 66
# tensor([736.0367], device='cuda:0')
# st: 180
# tensor([622.7311], device='cuda:0')
# st: 191
# tensor([610.7983], device='cuda:0')
# st: 201
# tensor([896.8932], device='cuda:0')
# st: 202
# tensor([648.0257], device='cuda:0')
# st: 212
# tensor([649.6575], device='cuda:0')
# st: 223
# tensor([598.7251], device='cuda:0')
# st: 233
# tensor([781.1328], device='cuda:0')
# st: 244
# tensor([611.6244], device='cuda:0')
# st: 255
# tensor([732.4247], device='cuda:0')
# st: 30
# tensor([627.4131], device='cuda:0')
# st: 66
# tensor([730.3343], device='cuda:0')
# st: 180
# tensor([618.1641], device='cuda:0')
# st: 191
# tensor([605.7053], device='cuda:0')
# st: 201
# tensor([890.4518], device='cuda:0')
# st: 202
# tensor([643.1804], device='cuda:0')
# st: 212
# tensor([644.2739], device='cuda:0')
# st: 223
# tensor([593.9827], device='cuda:0')
# st: 233
# tensor([775.6194], device='cuda:0')
# st: 244
# tensor([606.5267], device='cuda:0')
# st: 255
# tensor([727.1520], device='cuda:0')
# st: 30
# tensor([623.5145], device='cuda:0')
# st: 66
# tensor([725.0410], device='cuda:0')
# st: 180
# tensor([612.5237], device='cuda:0')
# st: 191
# tensor([600.9355], device='cuda:0')
# st: 201
# tensor([885.0295], device='cuda:0')
# st: 202
# tensor([638.3871], device='cuda:0')
# st: 212
# tensor([639.3416], device='cuda:0')
# st: 223
# tensor([589.5679], device='cuda:0')
# st: 233
# tensor([769.8972], device='cuda:0')
# st: 244
# tensor([601.7211], device='cuda:0')
# st: 255
# tensor([722.2073], device='cuda:0')
# st: 30
# tensor([618.9418], device='cuda:0')
# st: 66
# tensor([720.3752], device='cuda:0')
# st: 180
# tensor([609.1118], device='cuda:0')
# st: 191
# tensor([596.6489], device='cuda:0')
# st: 201
# tensor([879.6368], device='cuda:0')
# st: 202
# tensor([633.4872], device='cuda:0')
# st: 212
# tensor([634.1852], device='cuda:0')
# st: 223
# tensor([584.5416], device='cuda:0')
# st: 233
# tensor([763.5919], device='cuda:0')
# st: 244
# tensor([596.8571], device='cuda:0')
# st: 255
# tensor([717.0111], device='cuda:0')
# st: 30
# tensor([614.4179], device='cuda:0')
# st: 66
# tensor([714.1727], device='cuda:0')
# st: 180
# tensor([603.9598], device='cuda:0')
# st: 191
# tensor([591.0330], device='cuda:0')
# st: 201
# tensor([873.7350], device='cuda:0')
# st: 202
# tensor([628.9260], device='cuda:0')
# st: 212
# tensor([629.9243], device='cuda:0')
# st: 223
# tensor([579.6896], device='cuda:0')
# st: 233
# tensor([757.8723], device='cuda:0')
# st: 244
# tensor([592.2612], device='cuda:0')
# st: 255
# tensor([712.6054], device='cuda:0')
# st: 30
# tensor([609.3928], device='cuda:0')
# st: 66
# tensor([709.1577], device='cuda:0')
# st: 180
# tensor([599.4786], device='cuda:0')
# st: 191
# tensor([586.3113], device='cuda:0')
# st: 201
# tensor([868.3044], device='cuda:0')
# st: 202
# tensor([623.5471], device='cuda:0')
# st: 212
# tensor([625.0156], device='cuda:0')
# st: 223
# tensor([574.6976], device='cuda:0')
# st: 233
# tensor([752.0168], device='cuda:0')
# st: 244
# tensor([587.3945], device='cuda:0')
# st: 255
# tensor([705.9813], device='cuda:0')
# st: 30
# tensor([604.0087], device='cuda:0')
# st: 66
# tensor([704.1620], device='cuda:0')
# st: 180
# tensor([594.8278], device='cuda:0')
# st: 191
# tensor([581.7037], device='cuda:0')
# st: 201
# tensor([863.1111], device='cuda:0')
# st: 202
# tensor([618.7786], device='cuda:0')
# st: 212
# tensor([619.7282], device='cuda:0')
# st: 223
# tensor([570.0034], device='cuda:0')
# st: 233
# tensor([747.5865], device='cuda:0')
# st: 244
# tensor([582.3690], device='cuda:0')
# st: 255
# tensor([701.2769], device='cuda:0')
# st: 30
# tensor([599.0395], device='cuda:0')
# st: 66
# tensor([699.1863], device='cuda:0')
# st: 180
# tensor([590.3026], device='cuda:0')
# st: 191
# tensor([576.4247], device='cuda:0')
# st: 201
# tensor([856.6827], device='cuda:0')
# st: 202
# tensor([613.7565], device='cuda:0')
# st: 212
# tensor([614.5223], device='cuda:0')
# st: 223
# tensor([565.2914], device='cuda:0')
# st: 233
# tensor([741.5549], device='cuda:0')
# st: 244
# tensor([577.2102], device='cuda:0')
# st: 255
# tensor([695.4150], device='cuda:0')
# st: 30
# tensor([591.2056], device='cuda:0')
# st: 180
# tensor([581.3784], device='cuda:0')
# st: 191
# tensor([568.6373], device='cuda:0')
# st: 201
# tensor([848.9823], device='cuda:0')
# st: 202
# tensor([607.0070], device='cuda:0')
# st: 212
# tensor([607.4621], device='cuda:0')
# st: 223
# tensor([558.0434], device='cuda:0')
# st: 233
# tensor([732.9152], device='cuda:0')
# st: 244
# tensor([570.4988], device='cuda:0')
# st: 255
# tensor([689.2043], device='cuda:0')
# st: 30
# tensor([588.4009], device='cuda:0')
# st: 180
# tensor([578.7977], device='cuda:0')
# st: 191
# tensor([565.1645], device='cuda:0')
# st: 201
# tensor([845.7799], device='cuda:0')
# st: 202
# tensor([603.8116], device='cuda:0')
# st: 212
# tensor([603.8633], device='cuda:0')
# st: 223
# tensor([553.0591], device='cuda:0')
# st: 233
# tensor([730.4199], device='cuda:0')
# st: 244
# tensor([567.6006], device='cuda:0')
# st: 255
# tensor([684.4512], device='cuda:0')
# st: 30
# tensor([585.0963], device='cuda:0')
# st: 180
# tensor([575.9150], device='cuda:0')
# st: 191
# tensor([560.4738], device='cuda:0')
# st: 201
# tensor([841.4838], device='cuda:0')
# st: 202
# tensor([600.5245], device='cuda:0')
# st: 212
# tensor([600.4376], device='cuda:0')
# st: 223
# tensor([548.8234], device='cuda:0')
# st: 233
# tensor([727.2357], device='cuda:0')
# st: 244
# tensor([563.2790], device='cuda:0')
# st: 255
# tensor([681.8050], device='cuda:0')
# st: 30
# tensor([582.4220], device='cuda:0')
# st: 180
# tensor([572.4387], device='cuda:0')
# st: 191
# tensor([555.1898], device='cuda:0')
# st: 201
# tensor([836.9177], device='cuda:0')
# st: 202
# tensor([598.1699], device='cuda:0')
# st: 212
# tensor([597.5715], device='cuda:0')
# st: 223
# tensor([543.4489], device='cuda:0')
# st: 233
# tensor([723.3649], device='cuda:0')
# st: 244
# tensor([558.9490], device='cuda:0')
# st: 255
# tensor([678.5972], device='cuda:0')
# st: 30
# tensor([577.2668], device='cuda:0')
# st: 180
# tensor([566.9957], device='cuda:0')
# st: 191
# tensor([548.6763], device='cuda:0')
# st: 201
# tensor([831.2762], device='cuda:0')
# st: 202
# tensor([591.5745], device='cuda:0')
# st: 212
# tensor([591.0276], device='cuda:0')
# st: 223
# tensor([534.3517], device='cuda:0')
# st: 233
# tensor([717.1756], device='cuda:0')
# st: 244
# tensor([550.4434], device='cuda:0')
# st: 30
# tensor([573.9292], device='cuda:0')
# st: 180
# tensor([564.9662], device='cuda:0')
# st: 191
# tensor([545.1992], device='cuda:0')
# st: 201
# tensor([828.7508], device='cuda:0')
# st: 202
# tensor([590.0875], device='cuda:0')
# st: 212
# tensor([588.8926], device='cuda:0')
# st: 223
# tensor([533.4464], device='cuda:0')
# st: 233
# tensor([715.8123], device='cuda:0')
# st: 244
# tensor([548.4351], device='cuda:0')
# st: 30
# tensor([572.9542], device='cuda:0')
# st: 180
# tensor([563.2388], device='cuda:0')
# st: 191
# tensor([543.4722], device='cuda:0')
# st: 201
# tensor([827.4971], device='cuda:0')
# st: 202
# tensor([587.6569], device='cuda:0')
# st: 212
# tensor([587.1321], device='cuda:0')
# st: 223
# tensor([529.5523], device='cuda:0')
# st: 233
# tensor([712.7912], device='cuda:0')
# st: 244
# tensor([545.7255], device='cuda:0')
# st: 30
# tensor([570.3034], device='cuda:0')
# st: 180
# tensor([560.4250], device='cuda:0')
# st: 191
# tensor([539.7465], device='cuda:0')
# st: 201
# tensor([824.5060], device='cuda:0')
# st: 202
# tensor([585.5291], device='cuda:0')
# st: 212
# tensor([585.0513], device='cuda:0')
# st: 223
# tensor([528.3567], device='cuda:0')
# st: 233
# tensor([711.6865], device='cuda:0')
# st: 244
# tensor([543.3563], device='cuda:0')
# st: 30
# tensor([568.4665], device='cuda:0')
# st: 180
# tensor([557.4249], device='cuda:0')
# st: 191
# tensor([538.3773], device='cuda:0')
# st: 201
# tensor([822.7632], device='cuda:0')
# st: 202
# tensor([583.3433], device='cuda:0')
# st: 212
# tensor([583.7261], device='cuda:0')
# st: 223
# tensor([525.1401], device='cuda:0')
# st: 233
# tensor([708.5667], device='cuda:0')
# st: 244
# tensor([542.3211], device='cuda:0')
# st: 30
# tensor([565.8921], device='cuda:0')
# st: 180
# tensor([555.3572], device='cuda:0')
# st: 191
# tensor([537.1492], device='cuda:0')
# st: 201
# tensor([821.6598], device='cuda:0')
# st: 202
# tensor([581.9778], device='cuda:0')
# st: 212
# tensor([581.0959], device='cuda:0')
# st: 223
# tensor([523.4944], device='cuda:0')
# st: 233
# tensor([707.4492], device='cuda:0')
# st: 244
# tensor([539.1717], device='cuda:0')
# st: 30
# tensor([564.5732], device='cuda:0')
# st: 180
# tensor([552.5081], device='cuda:0')
# st: 191
# tensor([534.1289], device='cuda:0')
# st: 201
# tensor([818.8575], device='cuda:0')
# st: 202
# tensor([580.5008], device='cuda:0')
# st: 212
# tensor([579.5068], device='cuda:0')
# st: 223
# tensor([520.5952], device='cuda:0')
# st: 233
# tensor([705.2487], device='cuda:0')
# st: 244
# tensor([537.0585], device='cuda:0')
# st: 30
# tensor([562.6984], device='cuda:0')
# st: 180
# tensor([551.5113], device='cuda:0')
# st: 191
# tensor([531.8047], device='cuda:0')
# st: 201
# tensor([816.7504], device='cuda:0')
# st: 202
# tensor([577.7131], device='cuda:0')
# st: 212
# tensor([577.8785], device='cuda:0')
# st: 223
# tensor([518.8536], device='cuda:0')
# st: 233
# tensor([702.7227], device='cuda:0')
# st: 244
# tensor([534.3583], device='cuda:0')
# st: 30
# tensor([560.1328], device='cuda:0')
# st: 180
# tensor([548.0020], device='cuda:0')
# st: 191
# tensor([529.4963], device='cuda:0')
# st: 201
# tensor([814.1707], device='cuda:0')
# st: 202
# tensor([575.8781], device='cuda:0')
# st: 212
# tensor([575.1041], device='cuda:0')
# st: 223
# tensor([517.1791], device='cuda:0')
# st: 233
# tensor([701.0995], device='cuda:0')
# st: 244
# tensor([532.0235], device='cuda:0')
# st: 30
# tensor([558.9932], device='cuda:0')
# st: 180
# tensor([545.5840], device='cuda:0')
# st: 191
# tensor([527.2503], device='cuda:0')
# st: 201
# tensor([812.5547], device='cuda:0')
# st: 202
# tensor([572.6657], device='cuda:0')
# st: 212
# tensor([573.1201], device='cuda:0')
# st: 223
# tensor([514.2790], device='cuda:0')
# st: 233
# tensor([699.4725], device='cuda:0')
# st: 244
# tensor([529.7964], device='cuda:0')
# st: 30
# tensor([556.7623], device='cuda:0')
# st: 180
# tensor([544.7419], device='cuda:0')
# st: 191
# tensor([525.4560], device='cuda:0')
# st: 201
# tensor([810.5430], device='cuda:0')
# st: 202
# tensor([572.0538], device='cuda:0')
# st: 212
# tensor([571.2869], device='cuda:0')
# st: 223
# tensor([512.1129], device='cuda:0')
# st: 233
# tensor([697.8776], device='cuda:0')
# st: 244
# tensor([526.9052], device='cuda:0')
# st: 30
# tensor([554.6221], device='cuda:0')
# st: 180
# tensor([541.4274], device='cuda:0')
# st: 191
# tensor([522.2904], device='cuda:0')
# st: 201
# tensor([809.6253], device='cuda:0')
# st: 202
# tensor([570.8447], device='cuda:0')
# st: 212
# tensor([569.2404], device='cuda:0')
# st: 223
# tensor([509.0732], device='cuda:0')
# st: 233
# tensor([695.0477], device='cuda:0')
# st: 244
# tensor([524.4993], device='cuda:0')
# st: 30
# tensor([551.0329], device='cuda:0')
# st: 180
# tensor([539.3751], device='cuda:0')
# st: 191
# tensor([519.5042], device='cuda:0')
# st: 201
# tensor([806.2299], device='cuda:0')
# st: 202
# tensor([568.0261], device='cuda:0')
# st: 212
# tensor([566.4138], device='cuda:0')
# st: 223
# tensor([507.2424], device='cuda:0')
# st: 233
# tensor([693.1657], device='cuda:0')
# st: 244
# tensor([522.1754], device='cuda:0')
# st: 30
# tensor([549.3586], device='cuda:0')
# st: 180
# tensor([536.5496], device='cuda:0')
# st: 191
# tensor([517.1265], device='cuda:0')
# st: 201
# tensor([803.8614], device='cuda:0')
# st: 202
# tensor([566.4109], device='cuda:0')
# st: 212
# tensor([565.9363], device='cuda:0')
# st: 223
# tensor([504.2821], device='cuda:0')
# st: 233
# tensor([690.9854], device='cuda:0')
# st: 244
# tensor([521.1395], device='cuda:0')
# st: 30
# tensor([546.0787], device='cuda:0')
# st: 180
# tensor([533.7866], device='cuda:0')
# st: 191
# tensor([516.0919], device='cuda:0')
# st: 201
# tensor([803.0561], device='cuda:0')
# st: 202
# tensor([563.9605], device='cuda:0')
# st: 212
# tensor([563.0680], device='cuda:0')
# st: 223
# tensor([502.0639], device='cuda:0')
# st: 233
# tensor([689.4738], device='cuda:0')
# st: 244
# tensor([518.5142], device='cuda:0')
# st: 30
# tensor([543.6899], device='cuda:0')
# st: 180
# tensor([531.3747], device='cuda:0')
# st: 191
# tensor([513.7902], device='cuda:0')
# st: 201
# tensor([800.0375], device='cuda:0')
# st: 202
# tensor([562.3773], device='cuda:0')
# st: 212
# tensor([561.6848], device='cuda:0')
# st: 223
# tensor([500.0160], device='cuda:0')
# st: 233
# tensor([687.0148], device='cuda:0')
# st: 244
# tensor([516.4525], device='cuda:0')
# st: 30
# tensor([542.4991], device='cuda:0')
# st: 180
# tensor([530.3503], device='cuda:0')
# st: 191
# tensor([510.7646], device='cuda:0')
# st: 201
# tensor([798.7253], device='cuda:0')
# st: 202
# tensor([560.3361], device='cuda:0')
# st: 212
# tensor([559.5805], device='cuda:0')
# st: 223
# tensor([498.2361], device='cuda:0')
# st: 233
# tensor([685.6275], device='cuda:0')
# st: 244
# tensor([513.9485], device='cuda:0')
# st: 30
# tensor([539.0659], device='cuda:0')
# st: 180
# tensor([527.1475], device='cuda:0')
# st: 191
# tensor([508.5866], device='cuda:0')
# st: 201
# tensor([796.7173], device='cuda:0')
# st: 202
# tensor([558.2939], device='cuda:0')
# st: 212
# tensor([557.0865], device='cuda:0')
# st: 223
# tensor([495.2734], device='cuda:0')
# st: 233
# tensor([683.4614], device='cuda:0')
# st: 244
# tensor([510.9995], device='cuda:0')
# st: 30
# tensor([537.2323], device='cuda:0')
# st: 180
# tensor([524.3141], device='cuda:0')
# st: 191
# tensor([505.4837], device='cuda:0')
# st: 201
# tensor([793.9398], device='cuda:0')
# st: 202
# tensor([556.4306], device='cuda:0')
# st: 212
# tensor([555.3305], device='cuda:0')
# st: 223
# tensor([493.2393], device='cuda:0')
# st: 233
# tensor([681.2042], device='cuda:0')
# st: 244
# tensor([508.7564], device='cuda:0')
# st: 30
# tensor([534.7546], device='cuda:0')
# st: 180
# tensor([522.0972], device='cuda:0')
# st: 191
# tensor([503.9116], device='cuda:0')
# st: 201
# tensor([791.9871], device='cuda:0')
# st: 202
# tensor([554.3576], device='cuda:0')
# st: 212
# tensor([552.7524], device='cuda:0')
# st: 223
# tensor([490.8860], device='cuda:0')
# st: 233
# tensor([679.3683], device='cuda:0')
# st: 244
# tensor([505.2419], device='cuda:0')
# st: 30
# tensor([532.1924], device='cuda:0')
# st: 180
# tensor([519.7527], device='cuda:0')
# st: 191
# tensor([500.4194], device='cuda:0')
# st: 201
# tensor([789.4484], device='cuda:0')
# st: 202
# tensor([552.2874], device='cuda:0')
# st: 212
# tensor([551.2354], device='cuda:0')
# st: 223
# tensor([487.5909], device='cuda:0')
# st: 233
# tensor([677.5505], device='cuda:0')
# st: 244
# tensor([504.2727], device='cuda:0')
# st: 30
# tensor([528.9998], device='cuda:0')
# st: 180
# tensor([517.1101], device='cuda:0')
# st: 191
# tensor([499.2863], device='cuda:0')
# st: 201
# tensor([787.2561], device='cuda:0')
# st: 202
# tensor([550.5191], device='cuda:0')
# st: 212
# tensor([549.5228], device='cuda:0')
# st: 223
# tensor([485.8549], device='cuda:0')
# st: 233
# tensor([675.3522], device='cuda:0')
# st: 244
# tensor([501.4208], device='cuda:0')
# st: 30
# tensor([527.9518], device='cuda:0')
# st: 180
# tensor([515.0979], device='cuda:0')
# st: 191
# tensor([496.6584], device='cuda:0')
# st: 201
# tensor([785.5956], device='cuda:0')
# st: 202
# tensor([549.2213], device='cuda:0')
# st: 212
# tensor([547.5654], device='cuda:0')
# st: 223
# tensor([483.4378], device='cuda:0')
# st: 233
# tensor([673.0414], device='cuda:0')
# st: 244
# tensor([498.7961], device='cuda:0')
# st: 30
# tensor([524.8203], device='cuda:0')
# st: 180
# tensor([513.2355], device='cuda:0')
# st: 191
# tensor([494.2438], device='cuda:0')
# st: 201
# tensor([783.9233], device='cuda:0')
# st: 202
# tensor([546.2726], device='cuda:0')
# st: 212
# tensor([544.3766], device='cuda:0')
# st: 223
# tensor([481.7960], device='cuda:0')
# st: 233
# tensor([671.1699], device='cuda:0')
# st: 244
# tensor([496.5706], device='cuda:0')
# st: 30
# tensor([522.8047], device='cuda:0')
# st: 180
# tensor([510.8452], device='cuda:0')
# st: 191
# tensor([491.9146], device='cuda:0')
# st: 201
# tensor([782.1712], device='cuda:0')
# st: 202
# tensor([544.6765], device='cuda:0')
# st: 212
# tensor([542.3418], device='cuda:0')
# st: 223
# tensor([478.6419], device='cuda:0')
# st: 233
# tensor([668.8642], device='cuda:0')
# st: 244
# tensor([494.1714], device='cuda:0')
# st: 30
# tensor([519.8213], device='cuda:0')
# st: 180
# tensor([508.2988], device='cuda:0')
# st: 191
# tensor([489.5966], device='cuda:0')
# st: 201
# tensor([780.3153], device='cuda:0')
# st: 202
# tensor([541.1376], device='cuda:0')
# st: 212
# tensor([538.9651], device='cuda:0')
# st: 223
# tensor([476.6163], device='cuda:0')
# st: 233
# tensor([667.2466], device='cuda:0')
# st: 244
# tensor([492.2295], device='cuda:0')
# st: 30
# tensor([517.6158], device='cuda:0')
# st: 180
# tensor([505.5313], device='cuda:0')
# st: 191
# tensor([487.3102], device='cuda:0')
# st: 201
# tensor([777.4847], device='cuda:0')
# st: 202
# tensor([539.3937], device='cuda:0')
# st: 212
# tensor([537.1648], device='cuda:0')
# st: 223
# tensor([473.8571], device='cuda:0')
# st: 233
# tensor([664.3881], device='cuda:0')
# st: 244
# tensor([489.7465], device='cuda:0')
# st: 30
# tensor([515.9979], device='cuda:0')
# st: 180
# tensor([503.4236], device='cuda:0')
# st: 191
# tensor([485.6465], device='cuda:0')
# st: 201
# tensor([776.1436], device='cuda:0')
# st: 202
# tensor([536.6279], device='cuda:0')
# st: 212
# tensor([535.4679], device='cuda:0')
# st: 223
# tensor([471.8906], device='cuda:0')
# st: 233
# tensor([663.3308], device='cuda:0')
# st: 244
# tensor([487.6125], device='cuda:0')
# st: 30
# tensor([513.2135], device='cuda:0')
# st: 180
# tensor([499.9825], device='cuda:0')
# st: 191
# tensor([483.0838], device='cuda:0')
# st: 201
# tensor([772.6898], device='cuda:0')
# st: 202
# tensor([535.2535], device='cuda:0')
# st: 212
# tensor([532.4688], device='cuda:0')
# st: 223
# tensor([469.9725], device='cuda:0')
# st: 233
# tensor([661.0862], device='cuda:0')
# st: 244
# tensor([484.9521], device='cuda:0')
# st: 30
# tensor([511.2504], device='cuda:0')
# st: 180
# tensor([498.4415], device='cuda:0')
# st: 191
# tensor([479.8563], device='cuda:0')
# st: 201
# tensor([771.9721], device='cuda:0')
# st: 202
# tensor([532.2840], device='cuda:0')
# st: 212
# tensor([530.7165], device='cuda:0')
# st: 223
# tensor([467.9253], device='cuda:0')
# st: 233
# ...
# st: 271
# tensor([186.5541], device='cuda:0')
# st: 8
# tensor([171.1801], device='cuda:0')
# st: 36
# tensor([187.3728], device='cuda:0')
# st: 196
# tensor([343.3109], device='cuda:0')
# st: 207
# tensor([350.5377], device='cuda:0')
# st: 218
# tensor([224.4068], device='cuda:0')
# st: 228
# tensor([415.8797], device='cuda:0')
# st: 239
# tensor([292.3469], device='cuda:0')
# st: 249
# tensor([377.0610], device='cuda:0')
# st: 250
# tensor([218.5265], device='cuda:0')
# st: 260
# tensor([343.2612], device='cuda:0')
# st: 271
# tensor([182.1597], device='cuda:0')
# st: 8
# tensor([166.8410], device='cuda:0')
# st: 36
# tensor([183.3668], device='cuda:0')
# st: 196
# tensor([336.5684], device='cuda:0')
# st: 207
# tensor([343.1101], device='cuda:0')
# st: 218
# tensor([219.4055], device='cuda:0')
# st: 228
# tensor([409.2173], device='cuda:0')
# st: 239
# tensor([286.1688], device='cuda:0')
# st: 249
# tensor([370.1937], device='cuda:0')
# st: 250
# tensor([213.8352], device='cuda:0')
# st: 260
# tensor([336.2655], device='cuda:0')
# st: 271
# tensor([177.4955], device='cuda:0')
# st: 8
# tensor([162.6217], device='cuda:0')
# st: 36
# tensor([178.7942], device='cuda:0')
# st: 196
# tensor([329.6232], device='cuda:0')
# st: 207
# tensor([336.2365], device='cuda:0')
# st: 218
# tensor([214.9542], device='cuda:0')
# st: 228
# tensor([402.4915], device='cuda:0')
# st: 239
# tensor([279.6872], device='cuda:0')
# st: 249
# tensor([363.3797], device='cuda:0')
# st: 250
# tensor([209.0708], device='cuda:0')
# st: 260
# tensor([329.5524], device='cuda:0')
# st: 271
# tensor([173.0363], device='cuda:0')
# st: 8
# tensor([158.3881], device='cuda:0')
# st: 36
# tensor([174.0574], device='cuda:0')
# st: 196
# tensor([322.5895], device='cuda:0')
# st: 207
# tensor([329.5054], device='cuda:0')
# st: 218
# tensor([210.3796], device='cuda:0')
# st: 228
# tensor([395.8072], device='cuda:0')
# st: 239
# tensor([273.5385], device='cuda:0')
# st: 249
# tensor([357.1937], device='cuda:0')
# st: 250
# tensor([204.6448], device='cuda:0')
# st: 260
# tensor([322.2887], device='cuda:0')
# st: 271
# tensor([168.5984], device='cuda:0')
# st: 8
# tensor([154.5694], device='cuda:0')
# st: 36
# tensor([169.8156], device='cuda:0')
# st: 196
# tensor([315.6436], device='cuda:0')
# st: 207
# tensor([322.7742], device='cuda:0')
# st: 218
# tensor([205.6433], device='cuda:0')
# st: 228
# tensor([389.7580], device='cuda:0')
# st: 239
# tensor([267.6851], device='cuda:0')
# st: 249
# tensor([349.5546], device='cuda:0')
# st: 250
# tensor([199.9962], device='cuda:0')
# st: 260
# tensor([315.5001], device='cuda:0')
# st: 271
# tensor([164.5765], device='cuda:0')
# st: 8
# tensor([150.5423], device='cuda:0')
# st: 36
# tensor([165.6170], device='cuda:0')
# st: 196
# tensor([309.3287], device='cuda:0')
# st: 207
# tensor([315.6368], device='cuda:0')
# st: 218
# tensor([200.9814], device='cuda:0')
# st: 228
# tensor([383.1029], device='cuda:0')
# st: 239
# tensor([261.6753], device='cuda:0')
# st: 249
# tensor([342.7488], device='cuda:0')
# st: 250
# tensor([195.4392], device='cuda:0')
# st: 260
# tensor([308.5641], device='cuda:0')
# st: 271
# tensor([160.5370], device='cuda:0')
# st: 8
# tensor([147.6878], device='cuda:0')
# st: 36
# tensor([161.4831], device='cuda:0')
# st: 196
# tensor([302.4295], device='cuda:0')
# st: 207
# tensor([309.0448], device='cuda:0')
# st: 218
# tensor([196.5238], device='cuda:0')
# st: 228
# tensor([377.0262], device='cuda:0')
# st: 239
# tensor([255.5714], device='cuda:0')
# st: 249
# tensor([336.1858], device='cuda:0')
# st: 250
# tensor([190.6868], device='cuda:0')
# st: 260
# tensor([302.0444], device='cuda:0')
# st: 271
# tensor([156.2199], device='cuda:0')
# st: 8
# tensor([144.4763], device='cuda:0')
# st: 36
# tensor([157.1047], device='cuda:0')
# st: 196
# tensor([295.8499], device='cuda:0')
# st: 207
# tensor([302.1226], device='cuda:0')
# st: 218
# tensor([192.1649], device='cuda:0')
# st: 228
# tensor([369.2588], device='cuda:0')
# st: 239
# tensor([249.9801], device='cuda:0')
# st: 249
# tensor([329.4092], device='cuda:0')
# st: 250
# tensor([186.1448], device='cuda:0')
# st: 260
# tensor([294.9395], device='cuda:0')
# st: 271
# tensor([152.3646], device='cuda:0')
# st: 8
# tensor([141.6600], device='cuda:0')
# st: 36
# tensor([153.5009], device='cuda:0')
# st: 196
# tensor([288.9460], device='cuda:0')
# st: 207
# tensor([295.7753], device='cuda:0')
# st: 218
# tensor([187.3102], device='cuda:0')
# st: 228
# tensor([362.1307], device='cuda:0')
# st: 239
# tensor([244.2411], device='cuda:0')
# st: 249
# tensor([322.1837], device='cuda:0')
# st: 250
# tensor([181.4588], device='cuda:0')
# st: 260
# tensor([288.1258], device='cuda:0')
# st: 271
# tensor([149.2698], device='cuda:0')
# st: 8
# tensor([138.5683], device='cuda:0')
# st: 36
# tensor([150.6872], device='cuda:0')
# st: 196
# tensor([282.7625], device='cuda:0')
# st: 207
# tensor([288.8275], device='cuda:0')
# st: 218
# tensor([182.8601], device='cuda:0')
# st: 228
# tensor([355.5137], device='cuda:0')
# st: 239
# tensor([238.9366], device='cuda:0')
# st: 249
# tensor([315.5972], device='cuda:0')
# st: 250
# tensor([176.9491], device='cuda:0')
# st: 260
# tensor([282.1410], device='cuda:0')
# st: 271
# tensor([146.2328], device='cuda:0')
# st: 8
# tensor([135.8160], device='cuda:0')
# st: 36
# tensor([147.6791], device='cuda:0')
# st: 196
# tensor([275.9090], device='cuda:0')
# st: 207
# tensor([282.0391], device='cuda:0')
# st: 218
# tensor([177.7573], device='cuda:0')
# st: 228
# tensor([348.3236], device='cuda:0')
# st: 239
# tensor([233.0611], device='cuda:0')
# st: 249
# tensor([308.5227], device='cuda:0')
# st: 250
# tensor([172.7527], device='cuda:0')
# st: 260
# tensor([275.4672], device='cuda:0')
# st: 271
# tensor([143.2646], device='cuda:0')
# st: 36
# tensor([144.3157], device='cuda:0')
# st: 196
# tensor([268.4544], device='cuda:0')
# st: 207
# tensor([274.6058], device='cuda:0')
# st: 218
# tensor([173.3205], device='cuda:0')
# st: 228
# tensor([340.7060], device='cuda:0')
# st: 239
# tensor([227.5241], device='cuda:0')
# st: 249
# tensor([301.0434], device='cuda:0')
# st: 250
# tensor([167.9518], device='cuda:0')
# st: 260
# tensor([268.1873], device='cuda:0')
# st: 271
# tensor([139.9065], device='cuda:0')
# st: 36
# tensor([143.0420], device='cuda:0')
# st: 196
# tensor([265.9861], device='cuda:0')
# st: 207
# tensor([272.5708], device='cuda:0')
# st: 218
# tensor([171.5078], device='cuda:0')
# st: 228
# tensor([338.2918], device='cuda:0')
# st: 239
# tensor([225.6969], device='cuda:0')
# st: 249
# tensor([298.6316], device='cuda:0')
# st: 250
# tensor([166.5473], device='cuda:0')
# st: 260
# tensor([266.0664], device='cuda:0')
# st: 271
# tensor([138.8284], device='cuda:0')
# st: 36
# tensor([141.9757], device='cuda:0')
# st: 196
# tensor([263.8708], device='cuda:0')
# st: 207
# tensor([270.1564], device='cuda:0')
# st: 218
# tensor([169.9356], device='cuda:0')
# st: 228
# tensor([335.6054], device='cuda:0')
# st: 239
# tensor([223.5443], device='cuda:0')
# st: 249
# tensor([296.2355], device='cuda:0')
# st: 250
# tensor([164.7768], device='cuda:0')
# st: 260
# tensor([264.0093], device='cuda:0')
# st: 271
# tensor([137.5125], device='cuda:0')
# st: 36
# tensor([140.6455], device='cuda:0')
# st: 196
# tensor([261.8386], device='cuda:0')
# st: 207
# tensor([268.2834], device='cuda:0')
# st: 218
# tensor([168.1922], device='cuda:0')
# st: 228
# tensor([333.4702], device='cuda:0')
# st: 239
# tensor([221.8518], device='cuda:0')
# st: 249
# tensor([294.1667], device='cuda:0')
# st: 250
# tensor([163.6436], device='cuda:0')
# st: 260
# tensor([261.7931], device='cuda:0')
# st: 271
# tensor([136.2577], device='cuda:0')
# st: 36
# tensor([139.3404], device='cuda:0')
# st: 196
# tensor([259.5032], device='cuda:0')
# st: 207
# tensor([266.2370], device='cuda:0')
# st: 218
# tensor([166.4199], device='cuda:0')
# st: 228
# tensor([331.1660], device='cuda:0')
# st: 239
# tensor([220.0449], device='cuda:0')
# st: 249
# tensor([291.5316], device='cuda:0')
# st: 250
# tensor([162.4652], device='cuda:0')
# st: 260
# tensor([259.6187], device='cuda:0')
# st: 271
# tensor([134.9368], device='cuda:0')
# st: 36
# tensor([138.2513], device='cuda:0')
# st: 196
# tensor([257.4843], device='cuda:0')
# st: 207
# tensor([263.7625], device='cuda:0')
# st: 218
# tensor([164.9207], device='cuda:0')
# st: 228
# tensor([328.6365], device='cuda:0')
# st: 239
# tensor([217.7729], device='cuda:0')
# st: 249
# tensor([289.2837], device='cuda:0')
# st: 250
# tensor([160.8500], device='cuda:0')
# st: 260
# tensor([257.7125], device='cuda:0')
# st: 271
# tensor([133.5590], device='cuda:0')
# st: 36
# tensor([136.9718], device='cuda:0')
# st: 196
# tensor([255.4370], device='cuda:0')
# st: 207
# tensor([261.6494], device='cuda:0')
# st: 218
# tensor([163.6653], device='cuda:0')
# st: 228
# tensor([326.2568], device='cuda:0')
# st: 239
# tensor([216.1795], device='cuda:0')
# st: 249
# tensor([287.3037], device='cuda:0')
# st: 250
# tensor([159.6847], device='cuda:0')
# st: 260
# tensor([255.2873], device='cuda:0')
# st: 271
# tensor([132.7482], device='cuda:0')
# st: 36
# tensor([135.6751], device='cuda:0')
# st: 196
# tensor([252.9789], device='cuda:0')
# st: 207
# tensor([260.0726], device='cuda:0')
# st: 218
# tensor([162.2682], device='cuda:0')
# st: 228
# tensor([323.7507], device='cuda:0')
# st: 239
# tensor([214.1126], device='cuda:0')
# st: 249
# tensor([284.7060], device='cuda:0')
# st: 250
# tensor([158.4644], device='cuda:0')
# st: 260
# tensor([253.2800], device='cuda:0')
# st: 271
# tensor([131.3495], device='cuda:0')
# st: 36
# tensor([134.3878], device='cuda:0')
# st: 196
# tensor([251.0177], device='cuda:0')
# st: 207
# tensor([257.7765], device='cuda:0')
# st: 218
# tensor([161.0401], device='cuda:0')
# st: 228
# tensor([322.0952], device='cuda:0')
# st: 239
# tensor([212.2540], device='cuda:0')
# st: 249
# tensor([282.6156], device='cuda:0')
# st: 250
# tensor([156.9901], device='cuda:0')
# st: 260
# tensor([251.3072], device='cuda:0')
# st: 271
# tensor([130.0004], device='cuda:0')
# st: 36
# tensor([133.2866], device='cuda:0')
# st: 196
# tensor([249.1916], device='cuda:0')
# st: 207
# tensor([255.6772], device='cuda:0')
# st: 218
# tensor([159.6868], device='cuda:0')
# st: 228
# tensor([319.8312], device='cuda:0')
# st: 239
# tensor([210.6233], device='cuda:0')
# st: 249
# tensor([280.4801], device='cuda:0')
# st: 250
# tensor([155.7674], device='cuda:0')
# st: 260
# tensor([249.3211], device='cuda:0')
# st: 271
# tensor([128.8273], device='cuda:0')
# st: 36
# tensor([132.1210], device='cuda:0')
# st: 196
# tensor([246.8994], device='cuda:0')
# st: 207
# tensor([253.1834], device='cuda:0')
# st: 218
# tensor([158.6368], device='cuda:0')
# st: 228
# tensor([317.2531], device='cuda:0')
# st: 239
# tensor([208.6140], device='cuda:0')
# st: 249
# tensor([278.3563], device='cuda:0')
# st: 250
# tensor([154.6701], device='cuda:0')
# st: 260
# tensor([247.2326], device='cuda:0')
# st: 271
# tensor([127.5285], device='cuda:0')
# st: 36
# tensor([130.8300], device='cuda:0')
# st: 196
# tensor([245.0297], device='cuda:0')
# st: 207
# tensor([251.2623], device='cuda:0')
# st: 218
# tensor([157.3274], device='cuda:0')
# st: 228
# tensor([315.1590], device='cuda:0')
# st: 239
# tensor([207.0518], device='cuda:0')
# st: 249
# tensor([276.0976], device='cuda:0')
# st: 250
# tensor([153.0941], device='cuda:0')
# st: 260
# tensor([244.9795], device='cuda:0')
# st: 271
# tensor([126.1431], device='cuda:0')
# st: 36
# tensor([129.6104], device='cuda:0')
# st: 196
# tensor([242.7324], device='cuda:0')
# st: 207
# tensor([249.3103], device='cuda:0')
# st: 218
# tensor([156.0856], device='cuda:0')
# st: 228
# tensor([312.9425], device='cuda:0')
# st: 239
# tensor([205.3167], device='cuda:0')
# st: 249
# tensor([273.6044], device='cuda:0')
# st: 250
# tensor([152.0274], device='cuda:0')
# st: 260
# tensor([242.9592], device='cuda:0')
# st: 271
# tensor([124.9738], device='cuda:0')
# st: 36
# tensor([128.2298], device='cuda:0')
# st: 196
# tensor([240.8285], device='cuda:0')
# st: 207
# tensor([247.0162], device='cuda:0')
# st: 218
# tensor([154.9229], device='cuda:0')
# st: 228
# tensor([310.2467], device='cuda:0')
# st: 239
# tensor([203.5509], device='cuda:0')
# st: 249
# tensor([271.3505], device='cuda:0')
# st: 250
# tensor([150.6294], device='cuda:0')
# st: 260
# tensor([240.9498], device='cuda:0')
# st: 271
# tensor([123.6113], device='cuda:0')
# st: 36
# tensor([126.8484], device='cuda:0')
# st: 196
# tensor([238.7500], device='cuda:0')
# st: 207
# tensor([244.9770], device='cuda:0')
# st: 218
# tensor([153.5778], device='cuda:0')
# st: 228
# tensor([308.1416], device='cuda:0')
# st: 239
# tensor([201.6102], device='cuda:0')
# st: 249
# tensor([269.2894], device='cuda:0')
# st: 250
# tensor([149.4877], device='cuda:0')
# st: 260
# tensor([238.7849], device='cuda:0')
# st: 271
# tensor([122.3358], device='cuda:0')
# st: 36
# tensor([125.6401], device='cuda:0')
# st: 196
# tensor([236.7038], device='cuda:0')
# st: 207
# tensor([242.9613], device='cuda:0')
# st: 218
# tensor([152.3209], device='cuda:0')
# st: 228
# tensor([305.5431], device='cuda:0')
# st: 239
# tensor([200.0253], device='cuda:0')
# st: 249
# tensor([266.6703], device='cuda:0')
# st: 250
# tensor([148.2423], device='cuda:0')
# st: 260
# tensor([236.7859], device='cuda:0')
# st: 271
# tensor([120.8612], device='cuda:0')
# st: 36
# tensor([124.3169], device='cuda:0')
# st: 196
# tensor([234.5456], device='cuda:0')
# st: 207
# tensor([240.8443], device='cuda:0')
# st: 218
# tensor([151.2394], device='cuda:0')
# st: 228
# tensor([303.3016], device='cuda:0')
# st: 239
# tensor([197.8954], device='cuda:0')
# st: 249
# tensor([264.7072], device='cuda:0')
# st: 250
# tensor([146.8835], device='cuda:0')
# st: 260
# tensor([235.0633], device='cuda:0')
# st: 271
# tensor([119.8106], device='cuda:0')
# st: 36
# tensor([123.0048], device='cuda:0')
# st: 196
# tensor([232.9043], device='cuda:0')
# st: 207
# tensor([239.0300], device='cuda:0')
# st: 218
# tensor([149.9369], device='cuda:0')
# st: 228
# tensor([301.1565], device='cuda:0')
# st: 239
# tensor([196.3739], device='cuda:0')
# st: 249
# tensor([262.4935], device='cuda:0')
# st: 250
# tensor([145.6367], device='cuda:0')
# st: 260
# tensor([232.9891], device='cuda:0')
# st: 271
# tensor([118.4889], device='cuda:0')
# st: 36
# tensor([121.7906], device='cuda:0')
# st: 196
# tensor([230.4816], device='cuda:0')
# st: 207
# tensor([237.4247], device='cuda:0')
# st: 218
# tensor([148.5760], device='cuda:0')
# st: 228
# tensor([298.4402], device='cuda:0')
# st: 239
# tensor([194.5364], device='cuda:0')
# st: 249
# tensor([260.0349], device='cuda:0')
# st: 250
# tensor([144.4873], device='cuda:0')
# st: 260
# tensor([231.1195], device='cuda:0')
# st: 271
# tensor([117.1656], device='cuda:0')
# st: 36
# tensor([120.2618], device='cuda:0')
# st: 196
# tensor([228.6789], device='cuda:0')
# st: 207
# tensor([235.2554], device='cuda:0')
# st: 218
# tensor([147.5910], device='cuda:0')
# st: 228
# tensor([296.7025], device='cuda:0')
# st: 239
# tensor([192.6961], device='cuda:0')
# st: 249
# tensor([257.6208], device='cuda:0')
# st: 250
# tensor([143.0342], device='cuda:0')
# st: 260
# tensor([229.3434], device='cuda:0')
# st: 271
# tensor([115.9712], device='cuda:0')
# st: 36
# tensor([119.1167], device='cuda:0')
# st: 196
# tensor([226.8432], device='cuda:0')
# st: 207
# tensor([233.5277], device='cuda:0')
# st: 218
# tensor([146.1799], device='cuda:0')
# st: 228
# tensor([294.5714], device='cuda:0')
# st: 239
# tensor([191.1474], device='cuda:0')
# st: 249
# tensor([255.6958], device='cuda:0')
# st: 250
# tensor([141.9049], device='cuda:0')
# st: 260
# tensor([227.4715], device='cuda:0')
# st: 271
# tensor([114.6439], device='cuda:0')
# st: 36
# tensor([117.7516], device='cuda:0')
# st: 196
# tensor([224.9099], device='cuda:0')
# st: 207
# tensor([231.1748], device='cuda:0')
# st: 218
# tensor([144.9604], device='cuda:0')
# st: 228
# tensor([291.9075], device='cuda:0')
# st: 239
# tensor([189.2151], device='cuda:0')
# st: 249
# tensor([253.7338], device='cuda:0')
# st: 250
# tensor([140.7645], device='cuda:0')
# st: 260
# tensor([225.5258], device='cuda:0')
# st: 271
# tensor([113.4262], device='cuda:0')
# st: 36
# tensor([116.5461], device='cuda:0')
# st: 196
# tensor([223.1115], device='cuda:0')
# st: 207
# tensor([229.2936], device='cuda:0')
# st: 218
# tensor([143.7931], device='cuda:0')
# st: 228
# tensor([289.7308], device='cuda:0')
# st: 239
# tensor([187.8633], device='cuda:0')
# st: 249
# tensor([251.6358], device='cuda:0')
# st: 250
# tensor([139.3960], device='cuda:0')
# st: 260
# tensor([223.3890], device='cuda:0')
# st: 271
# tensor([111.9808], device='cuda:0')
# st: 36
# tensor([115.3810], device='cuda:0')
# st: 196
# tensor([220.9824], device='cuda:0')
# st: 207
# tensor([227.5513], device='cuda:0')
# st: 218
# tensor([142.4236], device='cuda:0')
# st: 228
# tensor([287.6137], device='cuda:0')
# st: 239
# tensor([186.1373], device='cuda:0')
# st: 249
# tensor([249.3891], device='cuda:0')
# st: 250
# tensor([138.1967], device='cuda:0')
# st: 260
# tensor([221.5657], device='cuda:0')
# st: 271
# tensor([110.6604], device='cuda:0')
# sim_time_percentage: 100%
# 25.0
# 0.0
# 2023-10-17 14:02:22.368289
# RL buffer size
# 3700
# 3700
# 3700
# ##########################

# %%
for i in range(0,6):
    print(t_agent.buffer.rewards[i])

# %%
'''Eichstatt_900_sec_100_slot_1_UE_4
Timeslot=200
Carrier_bandwidth=200

state

Demand=20
Num_of_macro=0
Num_of_micro=7
Time=900


Num_of_UE=10
Demand=200

Num_of_UE=100
Demand=20
'''
'''
state_dim = 186
#state_dim = 17
action_dim = 8
lr_actor = 0.003  
lr_critic = 0.001
gamma = 0.95
K_epochs = 15 
has_continuous_action_space=False
eps_clip = 0.2 
action_std = 0.6  
device = ppo_device
test = False
#Rand = random.randint(1,10)


if(os.path.exists(checkpoint_path)):
    
    t_agent.load(checkpoint_path)
    #t_agent.load(checkpoint_path,reward_table_checkpoint_path,critic_checkpoint_path)

for i in range(1):
    #power+=5
    
    print(Rand)
    print(Num_of_UE)
    lst_time,lst_QoS_1 = Dual_Connect.sim(algo=PPO_TF_HO_Algo,algo_name='PPO_TF_HO_Algo',timeslot=Timeslot,\
                    carrier_bandwidth=Carrier_bandwidth,
                    num_of_UE=Num_of_UE,demand=Demand,num_of_macro=Num_of_macro,\
                    num_of_micro=Num_of_micro,time=Time,RL_Agent=t_agent,\
                    time_step = time_step, power = power, time_th=max_training_timesteps/2,R =Rand)

    
    t_agent.buffer.clear()
    lst_time,lst_QoS_2 = Dual_Connect.sim(algo=Dual_Connect.Handover,algo_name='max_sinr',timeslot=Timeslot,\
                        carrier_bandwidth=Carrier_bandwidth,
                        num_of_UE=Num_of_UE,demand=Demand,num_of_macro=Num_of_macro,\
                        num_of_micro=Num_of_micro,time=Time, time_step = time_step,\
                                        time_th=max_training_timesteps/2,power = power, R=Rand )
'''
